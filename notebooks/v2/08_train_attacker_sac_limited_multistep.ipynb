# %% [markdown]
# Preparación del entorno

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from envs.v2.multi_step_limited_attack_env import AttackEnvLimitedMultiStep
from stable_baselines3.common.callbacks import BaseCallback
import matplotlib.pyplot as plt
import numpy as np
import joblib
from stable_baselines3 import SAC
from stable_baselines3 import PPO
from scipy.ndimage import uniform_filter1d
import os

# %% [markdown]
# Funciones Auxiliares

# %%
# Clase callback personalizada para logear y graficar
class AttackLoggerCallback(BaseCallback): # Extiende BaseCallback de stable-baselines3

    def __init__(self, log_freq: int = 1000, verbose: int = 0): # Muestra estadísticas cada 1000 episodios y pone el nivel de verbosidad a 0 por defecto (no muestra nada)
        super().__init__(verbose) # Llamamos al constructor padre con el nivel de verbosidad
        self.log_freq = log_freq # Muestra estadísticas cada log_freq episodios
        self.episode_count = 0 # Contador de episodios completados

        # Buffers por ventana (1000 episodios)
        self.rewards_buffer = [] # Buffer para recompensas
        self.success_buffer = [] # Buffer de veces que tuvo éxito
        self.p_attack_buffer = [] # Buffer de probabilidades de que el detector detecte el ataque
        self.dist_buffer = [] # Buffer de distancias entre x_adv y x_orig (tamaño de la perturbación)

        # Históricos completos para graficar
        self.history_episodes = []
        self.history_mean_reward = []
        self.history_success_rate = []
        self.history_mean_p_attack = []
        self.history_mean_dist = [] # Historial de distancia media por ventana

    def _on_step(self) -> bool:

        # Extraemos la información relevante del entorno
        infos = self.locals["infos"] # Información devuelta por el entorno
        rewards = self.locals["rewards"] # Recompensas obtenidas
        dones = self.locals["dones"] # Si el episodio ha terminado

        # Iteramos sobre la información, recompensas y estados de finalización
        for info, r, done in zip(infos, rewards, dones):

            # Si el episodio ha terminado
            if done:
                self.episode_count += 1 #  Incrementamos el contador de episodios
                self.rewards_buffer.append(float(r)) # Guardamos la recompensa obtenida

                # Si hubo éxito en el ataque
                if "success" in info:
                    self.success_buffer.append(int(info["success"])) # Guardamos si tuvo éxito

                # Si se proporciona la probabilidad de detección del ataque
                if "p_attack" in info:
                    self.p_attack_buffer.append(float(info["p_attack"])) # Guardamos la probabilidad de detección del ataque

                # Si se proporciona la distancia entre x_adv y x_orig
                if "dist" in info:
                    self.dist_buffer.append(float(info["dist"])) # Guardamos la distancia (magnitud de la perturbación)

                # Cada log_freq episodios, mostramos las estadísticas
                if self.episode_count > 0 and self.episode_count % self.log_freq == 0:

                    # Calculamos las métricas
                    mean_reward = np.mean(self.rewards_buffer) if self.rewards_buffer else 0.0 # Recompensa media
                    success_rate = np.mean(self.success_buffer) if self.success_buffer else 0.0 # Tasa de éxito
                    mean_p_attack = np.mean(self.p_attack_buffer) if self.p_attack_buffer else 0.0 # Probabilidad media de detección del ataque
                    mean_dist = np.mean(self.dist_buffer) if self.dist_buffer else 0.0 # Distancia media (tamaño medio de la perturbación)

                    # Guardamos las métricas en el histórico
                    self.history_episodes.append(self.episode_count) # Episodios completados
                    self.history_mean_reward.append(mean_reward) # Recompensa media
                    self.history_success_rate.append(success_rate) # Tasa de éxito
                    self.history_mean_p_attack.append(mean_p_attack) # Probabilidad media de detección del ataque
                    self.history_mean_dist.append(mean_dist) # Distancia media de la perturbación

                    # Mostramos las métricas por consola
                    print(
                        f"[AttackLogger] Episodios: {self.episode_count:6d} | "
                        f"Reward medio: {mean_reward: .3f} | "
                        f"Tasa éxito: {success_rate*100:5.1f}% | "
                        f"p_attack media: {mean_p_attack: .3f} | "
                        f"dist media: {mean_dist: .3f}"
                    )

                    # Limpiamos los buffers para la siguiente ventana
                    self.rewards_buffer.clear()
                    self.success_buffer.clear()
                    self.p_attack_buffer.clear()
                    self.dist_buffer.clear()

        return True

# %%
# Función para evaluar el agente SAC atacante
def evaluate_sac_attacker(model, env, n_episodes=500): # Evalúa el agente en el entorno dado durante n_episodes episodios
    
    # Variables para recuento
    successes = 0 # Contador de episodios exitosos
    total_steps = 0 # Contador de pasos totales
    final_p_attacks = [] # Lista para almacenar las probabilidades de que el ataque modificado sea detectado como ataque
    final_dists = [] # Lista para almacenar la distancia final entre x_adv y x_orig (tamaño de la perturbación)

    # Reseteamos el entorno
    obs = env.reset()

    # Iteramos por el numero de episodios a evaluar
    for _ in range(n_episodes):

        # Variables de control de finalización del episodio
        done = False
        truncated = False

        # Mientras no se termine el episodio
        while not (done or truncated):

            # Obtenemos la acción del modelo (determinística, ahora queremos el mejor ataque posible no explorar)
            action, _ = model.predict(obs, deterministic=True)

            # Ejecutamos la acción en el entorno y obtenemos los resultados
            obs, reward, done, info = env.step(action)

            # Cogemos el primer diccionario de info (entorno vectorizado, solo hay uno)
            info0 = info[0]

            # Parche para gym
            truncated = info0.get("terminal_observation") is not None if False else False  

            # Incrementamos el contador de pasos
            total_steps += 1

            # Si el valor de step_count es igual a max_steps del entorno
            if info0.get("step_count", 0) == env.get_attr("max_steps")[0]: 

                # Si el detector no detecta el ataque (pred = 0)
                if info0["pred"] == 0: 
                    successes += 1 # Incrementamos el contador de éxitos

                # Guardamos la probabilidad de que el defensor detecte el ataque modificado por el agente como ataque
                final_p_attacks.append(info0["p_attack"])

                # Guardamos la distancia final entre x_adv y x_orig
                if "dist" in info0:
                    final_dists.append(info0["dist"])

        # Reseteamos el entorno para el siguiente episodio
        obs = env.reset()

    # Calculamos las métricas finales
    success_rate = successes / n_episodes # Tasa de éxito, número de episodios exitosos dividido por el total de episodios
    mean_final_p = float(np.mean(final_p_attacks)) if final_p_attacks else None # Probabilidad media final de ataque
    mean_final_dist = float(np.mean(final_dists)) if final_dists else None # Distancia media final de la perturbación

    # Devolvemos las métricas
    return success_rate, mean_final_p, mean_final_dist

# %%
# Función para muestrear ataques adversariales completos (multi-step)
def sample_adversarials_multistep(model, env, n_episodes=200): # Agente SAC, entorno de ataque multi-step, número de episodios a muestrear

    # Listas para almacenar los ataques originales, finales y éxitos
    xs_orig = []
    xs_final = []
    successes = []
    dists = []  # Lista para almacenar la distancia final entre x_adv y x_orig

    # Reseteamos el entorno para el primer episodio
    obs = env.reset()

    # Obtenemos el número máximo de pasos por episodio del entorno
    max_steps = env.get_attr("max_steps")[0]

    # Iteramos por el número de episodios a muestrear
    for _ in range(n_episodes):

        # Variables de control de finalización del episodio
        done = False
        truncated = False
        
        # Variable para almacenar el ataque original del episodio
        x_orig_ep = None

        # Mientras no se termine el episodio
        while not (done or truncated):

            # Obtenemos la acción del agente (determinística)
            action, _ = model.predict(obs, deterministic=True)

            # Ejecutamos la acción en el entorno y obtenemos los resultados
            obs, rewards, dones, infos = env.step(action)

            # Cogemos la información del primer entorno (vectorizado, solo hay uno)
            info0 = infos[0]
            done = dones[0]

            # Guardamos el ataque original (es el del primer paso del episodio)
            if x_orig_ep is None and "x_orig" in info0:
                x_orig_ep = info0["x_orig"]

            # Detectar último paso del episodio
            step_count = info0.get("step_count", 0)
            is_last = (step_count == max_steps) or done

            # Si es el último paso del episodio
            if is_last:
                
                # Guardamos el ataque adversarial final
                x_adv_final = info0["x_adv"]

                # Guardamos si el ataque logró evadir el detector (pred = 0)
                pred_final = info0["pred"]  # 0 = normal, 1 = ataque

                # Almacenamos los resultados
                xs_orig.append(x_orig_ep)
                xs_final.append(x_adv_final)
                successes.append(1 if pred_final == 0 else 0)

                # Guardamos la distancia final si está disponible
                if "dist" in info0:
                    dists.append(info0["dist"])

                break

        # Siguiente episodio
        obs = env.reset()

    # Devolvemos los ataques originales, finales, éxitos y distancias como arrays de numpy
    return np.array(xs_orig), np.array(xs_final), np.array(successes), np.array(dists)

# %% [markdown]
# Creación del área de trabajo

# %%
# Carga del dataset
data = np.load("../../data/v2/synthetic_2d.npz")
X_train, X_test = data["X_train"], data["X_test"]
y_train, y_test = data["y_train"], data["y_test"]

# Cargamos solo muestras de ataque para el entorno
attack_mask = y_train == 1 # Crea un array booleano a true para muestras de ataque
attack_samples = X_train[attack_mask] # Nos quedamos solo con las muestras de ataque

# Carga del modelo clasificador
clf = joblib.load("../../classifiers/v2/logreg_synthetic_2d.joblib")

# Imprimimos la forma de las muestras de ataque
print("Attack samples:", attack_samples.shape)
# Out:
# Attack samples: (800, 2)

# %%
# Función para crear el entorno
def make_env():
    return AttackEnvLimitedMultiStep(
        attack_samples=attack_samples, # Lista de todas las muestras de ataque
        clf=clf, # Modelo clasificador
        threshold=0.5, # A partid de de esta probabilidad se considera que es ataque
        epsilon=0.7,   # Distancia máxima que el agente puede mofificar el punto original, aumentamos un poco
        penalty=0.01,  # Penalización suave por tamaño de la perturbación
        max_steps=5,   # 5 movimientos por ataque
    )

# Creamos el entorno vectorizado
venv = DummyVecEnv([make_env])

# Normalizamos las observaciones del entorno    
venv = VecNormalize(venv, norm_obs=True, norm_reward=False) # SAC trabaja mejor con observaciones normalizadas (entre 0 y 1)

# %% [markdown]
# Entrenamiento del agente SAC

# %%
# Architectura de la red neuronal del actor y crítico
policy_kwargs = dict(net_arch=[256, 256])

model = SAC(
    "MlpPolicy", # Redes totamente conectadas (MLP)
    venv, # Entorno vectorizado y normalizado
    verbose=0, # No muestra información durante el entrenamiento
    policy_kwargs=policy_kwargs, # Arquitectura de la red neuronal
    buffer_size=200_000, # SAC es off-policy y usa un buffer de replay para almacenar experiencias pasadas y aprender de ellas, cada train_freq aprende batch_size pasos aleatorios del buffer
    learning_rate=3e-4, # Tasa de aprendizaje, qué tanto se actualizan los pesos de la red neuronal en cada paso
    batch_size=256, # Los grupos en los que se divide cada actualización
    tau=0.02, # Velocidad de actualización de la red objetivo (Como el critico se actualiza en función del actor, valor pequeno significa actualizaciones lentas)(Actor decide que acciones tomar, critico evalua esas accionees)
    train_freq=1, # Cada cuántos pasos de entorno se realiza una actualización del modelo
    gradient_steps=1, # Número de actualizaciones del modelo por cada paso de entorno
)

# Creación del callback personalizado para logging
callback = AttackLoggerCallback(log_freq=100)

# Entrenamiento del agente SAC con 10,000 timesteps y el callback
model.learn(total_timesteps=50_000, callback=callback)

# Creamos la carpeta data sino existe
os.makedirs("../../agents/v2/", exist_ok=True)

# Guardamos el modelo entrenado y el entorno normalizado (SAC aprendio de un entorno normalizado, lo necesita para predecir)
model.save("../../agents/v2/sac_attacker_limited_multistep")
venv.save("../../agents/v2/sac_attacker_limited_multistep_vecnorm.pkl")
# Out:
# [AttackLogger] Episodios:    100 | Reward medio:  0.125 | Tasa éxito:  13.0% | p_attack media:  0.848 | dist media:  0.827
# [AttackLogger] Episodios:    200 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.837 | dist media:  0.852
# [AttackLogger] Episodios:    300 | Reward medio:  0.265 | Tasa éxito:  23.0% | p_attack media:  0.747 | dist media:  0.872
# [AttackLogger] Episodios:    400 | Reward medio:  0.302 | Tasa éxito:  29.0% | p_attack media:  0.688 | dist media:  0.928
# [AttackLogger] Episodios:    500 | Reward medio:  0.270 | Tasa éxito:  27.0% | p_attack media:  0.669 | dist media:  0.920
# [AttackLogger] Episodios:    600 | Reward medio:  0.212 | Tasa éxito:  21.0% | p_attack media:  0.731 | dist media:  0.981
# [AttackLogger] Episodios:    700 | Reward medio:  0.332 | Tasa éxito:  32.0% | p_attack media:  0.657 | dist media:  0.982
# [AttackLogger] Episodios:    800 | Reward medio:  0.234 | Tasa éxito:  23.0% | p_attack media:  0.702 | dist media:  0.982
# [AttackLogger] Episodios:    900 | Reward medio:  0.322 | Tasa éxito:  32.0% | p_attack media:  0.650 | dist media:  0.996
# [AttackLogger] Episodios:   1000 | Reward medio:  0.292 | Tasa éxito:  29.0% | p_attack media:  0.683 | dist media:  0.993
# [AttackLogger] Episodios:   1100 | Reward medio:  0.231 | Tasa éxito:  23.0% | p_attack media:  0.708 | dist media:  0.996
# [AttackLogger] Episodios:   1200 | Reward medio:  0.477 | Tasa éxito:  48.0% | p_attack media:  0.533 | dist media:  0.992
# [AttackLogger] Episodios:   1300 | Reward medio:  0.304 | Tasa éxito:  31.0% | p_attack media:  0.634 | dist media:  0.996
# [AttackLogger] Episodios:   1400 | Reward medio:  0.479 | Tasa éxito:  48.0% | p_attack media:  0.549 | dist media:  0.995
# [AttackLogger] Episodios:   1500 | Reward medio:  0.350 | Tasa éxito:  35.0% | p_attack media:  0.627 | dist media:  0.997
# [AttackLogger] Episodios:   1600 | Reward medio:  0.348 | Tasa éxito:  35.0% | p_attack media:  0.631 | dist media:  0.999
# [AttackLogger] Episodios:   1700 | Reward medio:  0.307 | Tasa éxito:  31.0% | p_attack media:  0.642 | dist media:  1.000
# [AttackLogger] Episodios:   1800 | Reward medio:  0.363 | Tasa éxito:  37.0% | p_attack media:  0.616 | dist media:  0.999
# [AttackLogger] Episodios:   1900 | Reward medio:  0.353 | Tasa éxito:  36.0% | p_attack media:  0.631 | dist media:  0.996
# [AttackLogger] Episodios:   2000 | Reward medio:  0.335 | Tasa éxito:  34.0% | p_attack media:  0.622 | dist media:  1.000
# [AttackLogger] Episodios:   2100 | Reward medio:  0.322 | Tasa éxito:  33.0% | p_attack media:  0.637 | dist media:  1.000
# [AttackLogger] Episodios:   2200 | Reward medio:  0.275 | Tasa éxito:  28.0% | p_attack media:  0.661 | dist media:  1.000
# [AttackLogger] Episodios:   2300 | Reward medio:  0.446 | Tasa éxito:  45.0% | p_attack media:  0.579 | dist media:  1.000
# [AttackLogger] Episodios:   2400 | Reward medio:  0.294 | Tasa éxito:  30.0% | p_attack media:  0.666 | dist media:  1.000
# [AttackLogger] Episodios:   2500 | Reward medio:  0.364 | Tasa éxito:  37.0% | p_attack media:  0.597 | dist media:  1.000
# [AttackLogger] Episodios:   2600 | Reward medio:  0.335 | Tasa éxito:  34.0% | p_attack media:  0.623 | dist media:  0.999
# [AttackLogger] Episodios:   2700 | Reward medio:  0.345 | Tasa éxito:  35.0% | p_attack media:  0.633 | dist media:  1.000
# [AttackLogger] Episodios:   2800 | Reward medio:  0.333 | Tasa éxito:  34.0% | p_attack media:  0.640 | dist media:  1.000
# [AttackLogger] Episodios:   2900 | Reward medio:  0.313 | Tasa éxito:  32.0% | p_attack media:  0.685 | dist media:  1.000
# [AttackLogger] Episodios:   3000 | Reward medio:  0.324 | Tasa éxito:  33.0% | p_attack media:  0.632 | dist media:  1.000
# [AttackLogger] Episodios:   3100 | Reward medio:  0.354 | Tasa éxito:  36.0% | p_attack media:  0.614 | dist media:  1.000
# [AttackLogger] Episodios:   3200 | Reward medio:  0.295 | Tasa éxito:  30.0% | p_attack media:  0.663 | dist media:  1.000
# [AttackLogger] Episodios:   3300 | Reward medio:  0.323 | Tasa éxito:  33.0% | p_attack media:  0.660 | dist media:  1.000
# [AttackLogger] Episodios:   3400 | Reward medio:  0.311 | Tasa éxito:  32.0% | p_attack media:  0.700 | dist media:  1.000
# [AttackLogger] Episodios:   3500 | Reward medio:  0.355 | Tasa éxito:  36.0% | p_attack media:  0.636 | dist media:  1.000
# [AttackLogger] Episodios:   3600 | Reward medio:  0.301 | Tasa éxito:  31.0% | p_attack media:  0.661 | dist media:  1.000
# [AttackLogger] Episodios:   3700 | Reward medio:  0.330 | Tasa éxito:  34.0% | p_attack media:  0.651 | dist media:  1.000
# [AttackLogger] Episodios:   3800 | Reward medio:  0.356 | Tasa éxito:  36.0% | p_attack media:  0.626 | dist media:  1.000
# [AttackLogger] Episodios:   3900 | Reward medio:  0.303 | Tasa éxito:  31.0% | p_attack media:  0.656 | dist media:  1.000
# [AttackLogger] Episodios:   4000 | Reward medio:  0.301 | Tasa éxito:  31.0% | p_attack media:  0.678 | dist media:  1.000
# [AttackLogger] Episodios:   4100 | Reward medio:  0.343 | Tasa éxito:  35.0% | p_attack media:  0.649 | dist media:  1.000
# [AttackLogger] Episodios:   4200 | Reward medio:  0.244 | Tasa éxito:  25.0% | p_attack media:  0.694 | dist media:  1.000
# [AttackLogger] Episodios:   4300 | Reward medio:  0.384 | Tasa éxito:  39.0% | p_attack media:  0.595 | dist media:  1.000
# [AttackLogger] Episodios:   4400 | Reward medio:  0.344 | Tasa éxito:  35.0% | p_attack media:  0.647 | dist media:  1.000
# [AttackLogger] Episodios:   4500 | Reward medio:  0.243 | Tasa éxito:  25.0% | p_attack media:  0.696 | dist media:  1.000
# [AttackLogger] Episodios:   4600 | Reward medio:  0.355 | Tasa éxito:  36.0% | p_attack media:  0.619 | dist media:  1.000
# [AttackLogger] Episodios:   4700 | Reward medio:  0.324 | Tasa éxito:  33.0% | p_attack media:  0.647 | dist media:  1.000
# [AttackLogger] Episodios:   4800 | Reward medio:  0.354 | Tasa éxito:  36.0% | p_attack media:  0.649 | dist media:  1.000
# [AttackLogger] Episodios:   4900 | Reward medio:  0.385 | Tasa éxito:  39.0% | p_attack media:  0.618 | dist media:  1.000
# [AttackLogger] Episodios:   5000 | Reward medio:  0.282 | Tasa éxito:  29.0% | p_attack media:  0.702 | dist media:  1.000
# [AttackLogger] Episodios:   5100 | Reward medio:  0.301 | Tasa éxito:  31.0% | p_attack media:  0.669 | dist media:  1.000
# [AttackLogger] Episodios:   5200 | Reward medio:  0.371 | Tasa éxito:  38.0% | p_attack media:  0.603 | dist media:  0.999
# [AttackLogger] Episodios:   5300 | Reward medio:  0.393 | Tasa éxito:  40.0% | p_attack media:  0.633 | dist media:  1.000
# [AttackLogger] Episodios:   5400 | Reward medio:  0.351 | Tasa éxito:  36.0% | p_attack media:  0.637 | dist media:  1.000
# [AttackLogger] Episodios:   5500 | Reward medio:  0.265 | Tasa éxito:  27.0% | p_attack media:  0.670 | dist media:  1.000
# [AttackLogger] Episodios:   5600 | Reward medio:  0.376 | Tasa éxito:  38.0% | p_attack media:  0.611 | dist media:  1.000
# [AttackLogger] Episodios:   5700 | Reward medio:  0.360 | Tasa éxito:  37.0% | p_attack media:  0.614 | dist media:  0.998
# [AttackLogger] Episodios:   5800 | Reward medio:  0.352 | Tasa éxito:  36.0% | p_attack media:  0.618 | dist media:  1.000
# [AttackLogger] Episodios:   5900 | Reward medio:  0.323 | Tasa éxito:  33.0% | p_attack media:  0.628 | dist media:  1.000
# [AttackLogger] Episodios:   6000 | Reward medio:  0.413 | Tasa éxito:  42.0% | p_attack media:  0.593 | dist media:  1.000
# [AttackLogger] Episodios:   6100 | Reward medio:  0.343 | Tasa éxito:  35.0% | p_attack media:  0.626 | dist media:  1.000
# [AttackLogger] Episodios:   6200 | Reward medio:  0.351 | Tasa éxito:  36.0% | p_attack media:  0.619 | dist media:  1.000
# [AttackLogger] Episodios:   6300 | Reward medio:  0.275 | Tasa éxito:  28.0% | p_attack media:  0.677 | dist media:  1.000
# [AttackLogger] Episodios:   6400 | Reward medio:  0.331 | Tasa éxito:  34.0% | p_attack media:  0.625 | dist media:  1.000
# [AttackLogger] Episodios:   6500 | Reward medio:  0.323 | Tasa éxito:  33.0% | p_attack media:  0.625 | dist media:  0.999
# [AttackLogger] Episodios:   6600 | Reward medio:  0.374 | Tasa éxito:  38.0% | p_attack media:  0.593 | dist media:  1.000
# [AttackLogger] Episodios:   6700 | Reward medio:  0.305 | Tasa éxito:  31.0% | p_attack media:  0.653 | dist media:  1.000
# [AttackLogger] Episodios:   6800 | Reward medio:  0.314 | Tasa éxito:  32.0% | p_attack media:  0.639 | dist media:  1.000
# [AttackLogger] Episodios:   6900 | Reward medio:  0.354 | Tasa éxito:  36.0% | p_attack media:  0.633 | dist media:  1.000
# [AttackLogger] Episodios:   7000 | Reward medio:  0.434 | Tasa éxito:  44.0% | p_attack media:  0.581 | dist media:  1.000
# [AttackLogger] Episodios:   7100 | Reward medio:  0.286 | Tasa éxito:  29.0% | p_attack media:  0.628 | dist media:  1.000
# [AttackLogger] Episodios:   7200 | Reward medio:  0.306 | Tasa éxito:  31.0% | p_attack media:  0.620 | dist media:  1.000
# [AttackLogger] Episodios:   7300 | Reward medio:  0.381 | Tasa éxito:  39.0% | p_attack media:  0.623 | dist media:  1.000
# [AttackLogger] Episodios:   7400 | Reward medio:  0.264 | Tasa éxito:  27.0% | p_attack media:  0.699 | dist media:  1.000
# [AttackLogger] Episodios:   7500 | Reward medio:  0.285 | Tasa éxito:  29.0% | p_attack media:  0.643 | dist media:  1.000
# [AttackLogger] Episodios:   7600 | Reward medio:  0.345 | Tasa éxito:  35.0% | p_attack media:  0.634 | dist media:  1.000
# [AttackLogger] Episodios:   7700 | Reward medio:  0.365 | Tasa éxito:  37.0% | p_attack media:  0.632 | dist media:  1.000
# [AttackLogger] Episodios:   7800 | Reward medio:  0.393 | Tasa éxito:  40.0% | p_attack media:  0.609 | dist media:  1.000
# [AttackLogger] Episodios:   7900 | Reward medio:  0.312 | Tasa éxito:  32.0% | p_attack media:  0.674 | dist media:  1.000
# [AttackLogger] Episodios:   8000 | Reward medio:  0.302 | Tasa éxito:  31.0% | p_attack media:  0.678 | dist media:  1.000
# [AttackLogger] Episodios:   8100 | Reward medio:  0.314 | Tasa éxito:  32.0% | p_attack media:  0.627 | dist media:  1.000
# [AttackLogger] Episodios:   8200 | Reward medio:  0.355 | Tasa éxito:  36.0% | p_attack media:  0.623 | dist media:  1.000
# [AttackLogger] Episodios:   8300 | Reward medio:  0.245 | Tasa éxito:  25.0% | p_attack media:  0.701 | dist media:  1.000
# [AttackLogger] Episodios:   8400 | Reward medio:  0.283 | Tasa éxito:  29.0% | p_attack media:  0.671 | dist media:  1.000
# [AttackLogger] Episodios:   8500 | Reward medio:  0.387 | Tasa éxito:  39.0% | p_attack media:  0.601 | dist media:  1.000
# [AttackLogger] Episodios:   8600 | Reward medio:  0.353 | Tasa éxito:  36.0% | p_attack media:  0.583 | dist media:  1.000
# [AttackLogger] Episodios:   8700 | Reward medio:  0.302 | Tasa éxito:  31.0% | p_attack media:  0.621 | dist media:  1.000
# [AttackLogger] Episodios:   8800 | Reward medio:  0.286 | Tasa éxito:  29.0% | p_attack media:  0.655 | dist media:  1.000
# [AttackLogger] Episodios:   8900 | Reward medio:  0.428 | Tasa éxito:  43.0% | p_attack media:  0.580 | dist media:  0.999
# [AttackLogger] Episodios:   9000 | Reward medio:  0.364 | Tasa éxito:  37.0% | p_attack media:  0.605 | dist media:  1.000
# [AttackLogger] Episodios:   9100 | Reward medio:  0.285 | Tasa éxito:  29.0% | p_attack media:  0.653 | dist media:  1.000
# [AttackLogger] Episodios:   9200 | Reward medio:  0.333 | Tasa éxito:  34.0% | p_attack media:  0.648 | dist media:  1.000
# [AttackLogger] Episodios:   9300 | Reward medio:  0.363 | Tasa éxito:  37.0% | p_attack media:  0.622 | dist media:  1.000
# [AttackLogger] Episodios:   9400 | Reward medio:  0.385 | Tasa éxito:  39.0% | p_attack media:  0.596 | dist media:  1.000
# [AttackLogger] Episodios:   9500 | Reward medio:  0.396 | Tasa éxito:  40.0% | p_attack media:  0.597 | dist media:  1.000
# [AttackLogger] Episodios:   9600 | Reward medio:  0.369 | Tasa éxito:  38.0% | p_attack media:  0.590 | dist media:  1.000
# [AttackLogger] Episodios:   9700 | Reward medio:  0.344 | Tasa éxito:  35.0% | p_attack media:  0.622 | dist media:  1.000
# [AttackLogger] Episodios:   9800 | Reward medio:  0.233 | Tasa éxito:  24.0% | p_attack media:  0.673 | dist media:  1.000
# [AttackLogger] Episodios:   9900 | Reward medio:  0.312 | Tasa éxito:  32.0% | p_attack media:  0.675 | dist media:  1.000
# [AttackLogger] Episodios:  10000 | Reward medio:  0.314 | Tasa éxito:  32.0% | p_attack media:  0.644 | dist media:  1.000

# %% [markdown]
# Gráficas de SAC

# %%
# Configuración de gráficos para visualizar los resultados
plt.style.use("seaborn-v0_8-whitegrid")

# Datos para graficar
episodes = np.array(callback.history_episodes)

# %%
# Gáfico de Tasa de éxito
success_rate = np.array(callback.history_success_rate) * 100

# Suavizado
window = 5
smooth_success = uniform_filter1d(success_rate, size=window)
mean = smooth_success
std = uniform_filter1d(np.abs(success_rate - mean), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Grafico de Tasa de éxito
plt.plot(episodes, mean, linewidth=2.2, color="#007acc")
plt.fill_between(
    episodes,
    mean - std,
    mean + std,
    color="#007acc",
    alpha=0.15
)
plt.title("Tasa de éxito del atacante", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Éxito (%)", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Reward medio
mean_reward = np.array(callback.history_mean_reward)

# Suavizado
window = 5
smooth_reward = uniform_filter1d(mean_reward, size=window)

# Desviación estándar local
std_reward = uniform_filter1d(np.abs(mean_reward - smooth_reward), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_reward, linewidth=2.2, color="#d35400")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_reward - std_reward,
    smooth_reward + std_reward,
    color="#d35400",
    alpha=0.15
)
plt.title("Reward medio por ventana (100 episodios)", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Reward", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Probabilidad media de ataque
mean_p_attack = np.array(callback.history_mean_p_attack)

# Suavizado
window = 5
smooth_p_attack = uniform_filter1d(mean_p_attack, size=window)

# Desviación estándar local
std_p_attack = uniform_filter1d(np.abs(mean_p_attack - smooth_p_attack), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_p_attack, linewidth=2.2, color="#8e44ad")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_p_attack - std_p_attack,
    smooth_p_attack + std_p_attack,
    color="#8e44ad",
    alpha=0.15
)
plt.title("Probabilidad media final de ataque", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("p_attack", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de SAC

# %%
# Creamos un entorno vectorizado para evaluación
eval_env = DummyVecEnv([make_env])

# Cargamos la normalización del entorno usado en entrenamiento
eval_env = VecNormalize.load("../../agents/v2/sac_attacker_limited_multistep_vecnorm.pkl", eval_env)

# Desactivamos el entrenamiento, de manera que las estadísticas de normalización no se actualicen durante la evaluación 
eval_env.training = False

# Desactivamos la normalización de recompensas para la evaluación (cuando evaluamos queremos las recompensas reales)
eval_env.norm_reward = False

# Cargamos el modelo entrenado
model = SAC.load("../../agents/v2/sac_attacker_limited_multistep")

# Evaluamos el agente SAC atacante con 300 episodios
success_rate, mean_final_p, mean_final_dist = evaluate_sac_attacker(model, eval_env, n_episodes=300)

# Mostramos los resultados finales de la evaluación
print(f"Tasa de evasión (episodio completo): {success_rate*100:.3f}%")
print(f"Probabilidad media final de ataque: {mean_final_p*100:.3f}%") # La probabilidad media de que el estado modificado por el agente sea catalogado como ataque
print(f"Distancia media final de la perturbación: {mean_final_dist:.3f}") # La distancia media entre x_adv y x_orig (tamaño medio de la perturbación)
# Out:
# Tasa de evasión (episodio completo): 28.667%
# Probabilidad media final de ataque: 66.436%
# Distancia media final de la perturbación: 1.000

# %% [markdown]
# Conclusiones de SAC

# %%
# Muestreamos 300 ataques adversariales generados por el agente SAC multi-step
xs_orig, xs_adv, successes, mean_final_dist = sample_adversarials_multistep(model, eval_env, n_episodes=300)

# Configuración de gráficos
plt.figure(figsize=(6, 6))

# Pintamos los ataques originales de color azul claro
plt.scatter(xs_orig[:, 0], xs_orig[:, 1], alpha=0.3, label="Original (ataque)")

# Pintamos los ataques adversariales que lograron evadir el detector de color naranja
mask_ok = successes == 1
plt.scatter(xs_adv[mask_ok, 0], xs_adv[mask_ok, 1], alpha=0.7, label="Adversarial (evade)")
plt.legend()
plt.grid(True)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Ataques adversariales aprendidos por el agente (multi-step SAC)")
plt.show()

# %% [markdown]
# Entrenamiento del agente PPO

# %%
# Arquitectura de la red neuronal del actor y crítico (PPO también usa MLP para policy y value)
policy_kwargs = dict(net_arch=[256, 256])

# Modelo PPO
model = PPO(
    "MlpPolicy",
    venv,  # Entorno vectorizado y normalizado
    verbose=0,  # No muestra info en consola (pon 1 si quieres ver logs)
    policy_kwargs=policy_kwargs,  # Arquitectura de la red
    learning_rate=3e-4,   # Tasa de aprendizaje
    n_steps=128,          # Pasos por actualización (pequeño porque tus episodios son muy cortos)
    batch_size=64,        # Tamaño de batch para actualizar
    gamma=0.99,           # Factor de descuento
    clip_range=0.2,       # Clip de PPO
    ent_coef=0.0,         # Coeficiente de entropía (0 si no quieres forzar exploración extra)
)

# Callback de logging (el mismo que ya tienes)
callback_PPO = AttackLoggerCallback(log_freq=100)

# Entrenamiento del agente PPO
model.learn(total_timesteps=100_000, callback=callback_PPO)

# Creamos la carpeta data sino existe
os.makedirs("../../agents/v2/", exist_ok=True)

# Guardamos el modelo entrenado y el entorno normalizado
model.save("../../agents/v2/ppo_attacker_limited_multistep_v2")
venv.save("../../agents/v2/ppo_attacker_limited_multistep_vecnorm_v2.pkl")
# Out:
# [AttackLogger] Episodios:    100 | Reward medio:  0.135 | Tasa éxito:  15.0% | p_attack media:  0.841 | dist media:  0.842
# [AttackLogger] Episodios:    200 | Reward medio:  0.234 | Tasa éxito:  24.0% | p_attack media:  0.745 | dist media:  0.890
# [AttackLogger] Episodios:    300 | Reward medio:  0.289 | Tasa éxito:  28.0% | p_attack media:  0.679 | dist media:  0.952
# [AttackLogger] Episodios:    400 | Reward medio:  0.241 | Tasa éxito:  25.0% | p_attack media:  0.642 | dist media:  0.990
# [AttackLogger] Episodios:    500 | Reward medio:  0.333 | Tasa éxito:  34.0% | p_attack media:  0.614 | dist media:  0.988
# [AttackLogger] Episodios:    600 | Reward medio:  0.385 | Tasa éxito:  39.0% | p_attack media:  0.602 | dist media:  0.991
# [AttackLogger] Episodios:    700 | Reward medio:  0.371 | Tasa éxito:  38.0% | p_attack media:  0.630 | dist media:  0.997
# [AttackLogger] Episodios:    800 | Reward medio:  0.282 | Tasa éxito:  28.0% | p_attack media:  0.690 | dist media:  0.997
# [AttackLogger] Episodios:    900 | Reward medio:  0.290 | Tasa éxito:  31.0% | p_attack media:  0.654 | dist media:  0.991
# [AttackLogger] Episodios:   1000 | Reward medio:  0.327 | Tasa éxito:  35.0% | p_attack media:  0.643 | dist media:  0.989
# [AttackLogger] Episodios:   1100 | Reward medio:  0.429 | Tasa éxito:  43.0% | p_attack media:  0.561 | dist media:  0.999
# [AttackLogger] Episodios:   1200 | Reward medio:  0.355 | Tasa éxito:  36.0% | p_attack media:  0.610 | dist media:  1.000
# [AttackLogger] Episodios:   1300 | Reward medio:  0.396 | Tasa éxito:  40.0% | p_attack media:  0.586 | dist media:  1.000
# [AttackLogger] Episodios:   1400 | Reward medio:  0.411 | Tasa éxito:  42.0% | p_attack media:  0.557 | dist media:  0.999
# [AttackLogger] Episodios:   1500 | Reward medio:  0.295 | Tasa éxito:  31.0% | p_attack media:  0.632 | dist media:  1.000
# [AttackLogger] Episodios:   1600 | Reward medio:  0.214 | Tasa éxito:  22.0% | p_attack media:  0.701 | dist media:  1.000
# [AttackLogger] Episodios:   1700 | Reward medio:  0.373 | Tasa éxito:  38.0% | p_attack media:  0.606 | dist media:  0.997
# [AttackLogger] Episodios:   1800 | Reward medio:  0.239 | Tasa éxito:  25.0% | p_attack media:  0.688 | dist media:  1.000
# [AttackLogger] Episodios:   1900 | Reward medio:  0.382 | Tasa éxito:  39.0% | p_attack media:  0.596 | dist media:  1.000
# [AttackLogger] Episodios:   2000 | Reward medio:  0.290 | Tasa éxito:  31.0% | p_attack media:  0.649 | dist media:  1.000
# [AttackLogger] Episodios:   2100 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.627 | dist media:  1.000
# [AttackLogger] Episodios:   2200 | Reward medio:  0.289 | Tasa éxito:  30.0% | p_attack media:  0.656 | dist media:  0.999
# [AttackLogger] Episodios:   2300 | Reward medio:  0.290 | Tasa éxito:  30.0% | p_attack media:  0.651 | dist media:  1.000
# [AttackLogger] Episodios:   2400 | Reward medio:  0.330 | Tasa éxito:  34.0% | p_attack media:  0.659 | dist media:  1.000
# [AttackLogger] Episodios:   2500 | Reward medio:  0.316 | Tasa éxito:  33.0% | p_attack media:  0.635 | dist media:  1.000
# [AttackLogger] Episodios:   2600 | Reward medio:  0.327 | Tasa éxito:  33.0% | p_attack media:  0.651 | dist media:  1.000
# [AttackLogger] Episodios:   2700 | Reward medio:  0.325 | Tasa éxito:  34.0% | p_attack media:  0.639 | dist media:  0.992
# [AttackLogger] Episodios:   2800 | Reward medio:  0.320 | Tasa éxito:  33.0% | p_attack media:  0.633 | dist media:  1.000
# [AttackLogger] Episodios:   2900 | Reward medio:  0.458 | Tasa éxito:  47.0% | p_attack media:  0.542 | dist media:  1.000
# [AttackLogger] Episodios:   3000 | Reward medio:  0.262 | Tasa éxito:  27.0% | p_attack media:  0.682 | dist media:  1.000
# [AttackLogger] Episodios:   3100 | Reward medio:  0.413 | Tasa éxito:  42.0% | p_attack media:  0.569 | dist media:  0.999
# [AttackLogger] Episodios:   3200 | Reward medio:  0.411 | Tasa éxito:  42.0% | p_attack media:  0.581 | dist media:  0.999
# [AttackLogger] Episodios:   3300 | Reward medio:  0.329 | Tasa éxito:  34.0% | p_attack media:  0.597 | dist media:  1.000
# [AttackLogger] Episodios:   3400 | Reward medio:  0.347 | Tasa éxito:  36.0% | p_attack media:  0.641 | dist media:  1.000
# [AttackLogger] Episodios:   3500 | Reward medio:  0.342 | Tasa éxito:  35.0% | p_attack media:  0.637 | dist media:  1.000
# [AttackLogger] Episodios:   3600 | Reward medio:  0.361 | Tasa éxito:  37.0% | p_attack media:  0.596 | dist media:  1.000
# [AttackLogger] Episodios:   3700 | Reward medio:  0.390 | Tasa éxito:  40.0% | p_attack media:  0.618 | dist media:  0.997
# [AttackLogger] Episodios:   3800 | Reward medio:  0.297 | Tasa éxito:  30.0% | p_attack media:  0.657 | dist media:  1.000
# [AttackLogger] Episodios:   3900 | Reward medio:  0.320 | Tasa éxito:  33.0% | p_attack media:  0.637 | dist media:  0.999
# [AttackLogger] Episodios:   4000 | Reward medio:  0.351 | Tasa éxito:  36.0% | p_attack media:  0.625 | dist media:  0.998
# [AttackLogger] Episodios:   4100 | Reward medio:  0.293 | Tasa éxito:  30.0% | p_attack media:  0.650 | dist media:  0.994
# [AttackLogger] Episodios:   4200 | Reward medio:  0.267 | Tasa éxito:  27.0% | p_attack media:  0.673 | dist media:  0.997
# [AttackLogger] Episodios:   4300 | Reward medio:  0.259 | Tasa éxito:  28.0% | p_attack media:  0.677 | dist media:  0.983
# [AttackLogger] Episodios:   4400 | Reward medio:  0.331 | Tasa éxito:  34.0% | p_attack media:  0.622 | dist media:  0.998
# [AttackLogger] Episodios:   4500 | Reward medio:  0.342 | Tasa éxito:  35.0% | p_attack media:  0.661 | dist media:  1.000
# [AttackLogger] Episodios:   4600 | Reward medio:  0.332 | Tasa éxito:  35.0% | p_attack media:  0.650 | dist media:  0.996
# [AttackLogger] Episodios:   4700 | Reward medio:  0.339 | Tasa éxito:  35.0% | p_attack media:  0.632 | dist media:  0.986
# [AttackLogger] Episodios:   4800 | Reward medio:  0.365 | Tasa éxito:  37.0% | p_attack media:  0.616 | dist media:  0.996
# [AttackLogger] Episodios:   4900 | Reward medio:  0.319 | Tasa éxito:  33.0% | p_attack media:  0.629 | dist media:  0.987
# [AttackLogger] Episodios:   5000 | Reward medio:  0.325 | Tasa éxito:  34.0% | p_attack media:  0.630 | dist media:  1.000
# [AttackLogger] Episodios:   5100 | Reward medio:  0.360 | Tasa éxito:  36.0% | p_attack media:  0.610 | dist media:  0.995
# [AttackLogger] Episodios:   5200 | Reward medio:  0.340 | Tasa éxito:  35.0% | p_attack media:  0.633 | dist media:  1.000
# [AttackLogger] Episodios:   5300 | Reward medio:  0.311 | Tasa éxito:  32.0% | p_attack media:  0.665 | dist media:  0.995
# [AttackLogger] Episodios:   5400 | Reward medio:  0.343 | Tasa éxito:  36.0% | p_attack media:  0.603 | dist media:  0.997
# [AttackLogger] Episodios:   5500 | Reward medio:  0.241 | Tasa éxito:  25.0% | p_attack media:  0.705 | dist media:  0.999
# [AttackLogger] Episodios:   5600 | Reward medio:  0.365 | Tasa éxito:  38.0% | p_attack media:  0.588 | dist media:  0.999
# [AttackLogger] Episodios:   5700 | Reward medio:  0.330 | Tasa éxito:  34.0% | p_attack media:  0.658 | dist media:  1.000
# [AttackLogger] Episodios:   5800 | Reward medio:  0.271 | Tasa éxito:  28.0% | p_attack media:  0.668 | dist media:  0.998
# [AttackLogger] Episodios:   5900 | Reward medio:  0.350 | Tasa éxito:  36.0% | p_attack media:  0.628 | dist media:  1.000
# [AttackLogger] Episodios:   6000 | Reward medio:  0.419 | Tasa éxito:  43.0% | p_attack media:  0.577 | dist media:  1.000
# [AttackLogger] Episodios:   6100 | Reward medio:  0.290 | Tasa éxito:  30.0% | p_attack media:  0.637 | dist media:  1.000
# [AttackLogger] Episodios:   6200 | Reward medio:  0.271 | Tasa éxito:  28.0% | p_attack media:  0.683 | dist media:  1.000
# [AttackLogger] Episodios:   6300 | Reward medio:  0.331 | Tasa éxito:  34.0% | p_attack media:  0.614 | dist media:  1.000
# [AttackLogger] Episodios:   6400 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.632 | dist media:  1.000
# [AttackLogger] Episodios:   6500 | Reward medio:  0.315 | Tasa éxito:  32.0% | p_attack media:  0.644 | dist media:  1.000
# [AttackLogger] Episodios:   6600 | Reward medio:  0.312 | Tasa éxito:  32.0% | p_attack media:  0.652 | dist media:  1.000
# [AttackLogger] Episodios:   6700 | Reward medio:  0.303 | Tasa éxito:  31.0% | p_attack media:  0.645 | dist media:  1.000
# [AttackLogger] Episodios:   6800 | Reward medio:  0.291 | Tasa éxito:  30.0% | p_attack media:  0.663 | dist media:  1.000
# [AttackLogger] Episodios:   6900 | Reward medio:  0.371 | Tasa éxito:  38.0% | p_attack media:  0.589 | dist media:  1.000
# [AttackLogger] Episodios:   7000 | Reward medio:  0.458 | Tasa éxito:  47.0% | p_attack media:  0.563 | dist media:  1.000
# [AttackLogger] Episodios:   7100 | Reward medio:  0.316 | Tasa éxito:  32.0% | p_attack media:  0.643 | dist media:  1.000
# [AttackLogger] Episodios:   7200 | Reward medio:  0.316 | Tasa éxito:  33.0% | p_attack media:  0.613 | dist media:  1.000
# [AttackLogger] Episodios:   7300 | Reward medio:  0.340 | Tasa éxito:  35.0% | p_attack media:  0.629 | dist media:  1.000
# [AttackLogger] Episodios:   7400 | Reward medio:  0.330 | Tasa éxito:  34.0% | p_attack media:  0.644 | dist media:  1.000
# [AttackLogger] Episodios:   7500 | Reward medio:  0.279 | Tasa éxito:  29.0% | p_attack media:  0.668 | dist media:  1.000
# [AttackLogger] Episodios:   7600 | Reward medio:  0.302 | Tasa éxito:  31.0% | p_attack media:  0.673 | dist media:  1.000
# [AttackLogger] Episodios:   7700 | Reward medio:  0.333 | Tasa éxito:  34.0% | p_attack media:  0.596 | dist media:  1.000
# [AttackLogger] Episodios:   7800 | Reward medio:  0.299 | Tasa éxito:  31.0% | p_attack media:  0.654 | dist media:  1.000
# [AttackLogger] Episodios:   7900 | Reward medio:  0.368 | Tasa éxito:  38.0% | p_attack media:  0.601 | dist media:  1.000
# [AttackLogger] Episodios:   8000 | Reward medio:  0.415 | Tasa éxito:  42.0% | p_attack media:  0.561 | dist media:  1.000
# [AttackLogger] Episodios:   8100 | Reward medio:  0.320 | Tasa éxito:  33.0% | p_attack media:  0.659 | dist media:  1.000
# [AttackLogger] Episodios:   8200 | Reward medio:  0.382 | Tasa éxito:  39.0% | p_attack media:  0.622 | dist media:  1.000
# [AttackLogger] Episodios:   8300 | Reward medio:  0.275 | Tasa éxito:  29.0% | p_attack media:  0.638 | dist media:  1.000
# [AttackLogger] Episodios:   8400 | Reward medio:  0.411 | Tasa éxito:  42.0% | p_attack media:  0.573 | dist media:  1.000
# [AttackLogger] Episodios:   8500 | Reward medio:  0.279 | Tasa éxito:  29.0% | p_attack media:  0.646 | dist media:  1.000
# [AttackLogger] Episodios:   8600 | Reward medio:  0.377 | Tasa éxito:  39.0% | p_attack media:  0.618 | dist media:  1.000
# [AttackLogger] Episodios:   8700 | Reward medio:  0.332 | Tasa éxito:  34.0% | p_attack media:  0.630 | dist media:  1.000
# [AttackLogger] Episodios:   8800 | Reward medio:  0.306 | Tasa éxito:  31.0% | p_attack media:  0.647 | dist media:  1.000
# [AttackLogger] Episodios:   8900 | Reward medio:  0.361 | Tasa éxito:  37.0% | p_attack media:  0.623 | dist media:  1.000
# [AttackLogger] Episodios:   9000 | Reward medio:  0.380 | Tasa éxito:  39.0% | p_attack media:  0.613 | dist media:  1.000
# [AttackLogger] Episodios:   9100 | Reward medio:  0.384 | Tasa éxito:  39.0% | p_attack media:  0.595 | dist media:  1.000
# [AttackLogger] Episodios:   9200 | Reward medio:  0.294 | Tasa éxito:  30.0% | p_attack media:  0.642 | dist media:  1.000
# [AttackLogger] Episodios:   9300 | Reward medio:  0.301 | Tasa éxito:  31.0% | p_attack media:  0.658 | dist media:  1.000
# [AttackLogger] Episodios:   9400 | Reward medio:  0.309 | Tasa éxito:  32.0% | p_attack media:  0.639 | dist media:  1.000
# [AttackLogger] Episodios:   9500 | Reward medio:  0.349 | Tasa éxito:  36.0% | p_attack media:  0.630 | dist media:  1.000
# [AttackLogger] Episodios:   9600 | Reward medio:  0.407 | Tasa éxito:  42.0% | p_attack media:  0.587 | dist media:  1.000
# [AttackLogger] Episodios:   9700 | Reward medio:  0.371 | Tasa éxito:  38.0% | p_attack media:  0.586 | dist media:  1.000
# [AttackLogger] Episodios:   9800 | Reward medio:  0.322 | Tasa éxito:  33.0% | p_attack media:  0.646 | dist media:  1.000
# [AttackLogger] Episodios:   9900 | Reward medio:  0.326 | Tasa éxito:  34.0% | p_attack media:  0.631 | dist media:  1.000
# [AttackLogger] Episodios:  10000 | Reward medio:  0.270 | Tasa éxito:  28.0% | p_attack media:  0.674 | dist media:  1.000
# [AttackLogger] Episodios:  10100 | Reward medio:  0.370 | Tasa éxito:  38.0% | p_attack media:  0.597 | dist media:  1.000
# [AttackLogger] Episodios:  10200 | Reward medio:  0.371 | Tasa éxito:  38.0% | p_attack media:  0.602 | dist media:  1.000
# [AttackLogger] Episodios:  10300 | Reward medio:  0.200 | Tasa éxito:  21.0% | p_attack media:  0.728 | dist media:  1.000
# [AttackLogger] Episodios:  10400 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.624 | dist media:  1.000
# [AttackLogger] Episodios:  10500 | Reward medio:  0.310 | Tasa éxito:  32.0% | p_attack media:  0.656 | dist media:  1.000
# [AttackLogger] Episodios:  10600 | Reward medio:  0.371 | Tasa éxito:  38.0% | p_attack media:  0.607 | dist media:  1.000
# [AttackLogger] Episodios:  10700 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.654 | dist media:  1.000
# [AttackLogger] Episodios:  10800 | Reward medio:  0.381 | Tasa éxito:  39.0% | p_attack media:  0.576 | dist media:  1.000
# [AttackLogger] Episodios:  10900 | Reward medio:  0.320 | Tasa éxito:  33.0% | p_attack media:  0.643 | dist media:  1.000
# [AttackLogger] Episodios:  11000 | Reward medio:  0.340 | Tasa éxito:  35.0% | p_attack media:  0.638 | dist media:  1.000
# [AttackLogger] Episodios:  11100 | Reward medio:  0.350 | Tasa éxito:  36.0% | p_attack media:  0.592 | dist media:  1.000
# [AttackLogger] Episodios:  11200 | Reward medio:  0.380 | Tasa éxito:  39.0% | p_attack media:  0.601 | dist media:  1.000
# [AttackLogger] Episodios:  11300 | Reward medio:  0.343 | Tasa éxito:  35.0% | p_attack media:  0.654 | dist media:  1.000
# [AttackLogger] Episodios:  11400 | Reward medio:  0.300 | Tasa éxito:  31.0% | p_attack media:  0.623 | dist media:  1.000
# [AttackLogger] Episodios:  11500 | Reward medio:  0.370 | Tasa éxito:  38.0% | p_attack media:  0.586 | dist media:  1.000
# [AttackLogger] Episodios:  11600 | Reward medio:  0.340 | Tasa éxito:  35.0% | p_attack media:  0.604 | dist media:  1.000
# [AttackLogger] Episodios:  11700 | Reward medio:  0.322 | Tasa éxito:  33.0% | p_attack media:  0.635 | dist media:  1.000
# [AttackLogger] Episodios:  11800 | Reward medio:  0.382 | Tasa éxito:  39.0% | p_attack media:  0.597 | dist media:  1.000
# [AttackLogger] Episodios:  11900 | Reward medio:  0.309 | Tasa éxito:  32.0% | p_attack media:  0.684 | dist media:  1.000
# [AttackLogger] Episodios:  12000 | Reward medio:  0.380 | Tasa éxito:  39.0% | p_attack media:  0.593 | dist media:  1.000
# [AttackLogger] Episodios:  12100 | Reward medio:  0.341 | Tasa éxito:  35.0% | p_attack media:  0.633 | dist media:  1.000
# [AttackLogger] Episodios:  12200 | Reward medio:  0.358 | Tasa éxito:  37.0% | p_attack media:  0.615 | dist media:  0.999
# [AttackLogger] Episodios:  12300 | Reward medio:  0.311 | Tasa éxito:  32.0% | p_attack media:  0.640 | dist media:  1.000
# [AttackLogger] Episodios:  12400 | Reward medio:  0.351 | Tasa éxito:  36.0% | p_attack media:  0.597 | dist media:  1.000
# [AttackLogger] Episodios:  12500 | Reward medio:  0.262 | Tasa éxito:  27.0% | p_attack media:  0.658 | dist media:  1.000
# [AttackLogger] Episodios:  12600 | Reward medio:  0.369 | Tasa éxito:  38.0% | p_attack media:  0.599 | dist media:  1.000
# [AttackLogger] Episodios:  12700 | Reward medio:  0.310 | Tasa éxito:  32.0% | p_attack media:  0.619 | dist media:  0.992
# [AttackLogger] Episodios:  12800 | Reward medio:  0.270 | Tasa éxito:  28.0% | p_attack media:  0.676 | dist media:  1.000
# [AttackLogger] Episodios:  12900 | Reward medio:  0.347 | Tasa éxito:  36.0% | p_attack media:  0.654 | dist media:  1.000
# [AttackLogger] Episodios:  13000 | Reward medio:  0.319 | Tasa éxito:  33.0% | p_attack media:  0.641 | dist media:  1.000
# [AttackLogger] Episodios:  13100 | Reward medio:  0.273 | Tasa éxito:  28.0% | p_attack media:  0.666 | dist media:  0.996
# [AttackLogger] Episodios:  13200 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.641 | dist media:  1.000
# [AttackLogger] Episodios:  13300 | Reward medio:  0.369 | Tasa éxito:  38.0% | p_attack media:  0.602 | dist media:  0.994
# [AttackLogger] Episodios:  13400 | Reward medio:  0.282 | Tasa éxito:  29.0% | p_attack media:  0.659 | dist media:  1.000
# [AttackLogger] Episodios:  13500 | Reward medio:  0.410 | Tasa éxito:  42.0% | p_attack media:  0.577 | dist media:  1.000
# [AttackLogger] Episodios:  13600 | Reward medio:  0.382 | Tasa éxito:  39.0% | p_attack media:  0.614 | dist media:  1.000
# [AttackLogger] Episodios:  13700 | Reward medio:  0.359 | Tasa éxito:  37.0% | p_attack media:  0.617 | dist media:  1.000
# [AttackLogger] Episodios:  13800 | Reward medio:  0.316 | Tasa éxito:  33.0% | p_attack media:  0.660 | dist media:  1.000
# [AttackLogger] Episodios:  13900 | Reward medio:  0.422 | Tasa éxito:  43.0% | p_attack media:  0.594 | dist media:  1.000
# [AttackLogger] Episodios:  14000 | Reward medio:  0.292 | Tasa éxito:  30.0% | p_attack media:  0.648 | dist media:  1.000
# [AttackLogger] Episodios:  14100 | Reward medio:  0.415 | Tasa éxito:  42.0% | p_attack media:  0.591 | dist media:  1.000
# [AttackLogger] Episodios:  14200 | Reward medio:  0.290 | Tasa éxito:  30.0% | p_attack media:  0.660 | dist media:  1.000
# [AttackLogger] Episodios:  14300 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.656 | dist media:  1.000
# [AttackLogger] Episodios:  14400 | Reward medio:  0.397 | Tasa éxito:  41.0% | p_attack media:  0.584 | dist media:  1.000
# [AttackLogger] Episodios:  14500 | Reward medio:  0.279 | Tasa éxito:  29.0% | p_attack media:  0.675 | dist media:  1.000
# [AttackLogger] Episodios:  14600 | Reward medio:  0.361 | Tasa éxito:  37.0% | p_attack media:  0.613 | dist media:  1.000
# [AttackLogger] Episodios:  14700 | Reward medio:  0.334 | Tasa éxito:  34.0% | p_attack media:  0.622 | dist media:  1.000
# [AttackLogger] Episodios:  14800 | Reward medio:  0.309 | Tasa éxito:  32.0% | p_attack media:  0.652 | dist media:  1.000
# [AttackLogger] Episodios:  14900 | Reward medio:  0.331 | Tasa éxito:  34.0% | p_attack media:  0.605 | dist media:  1.000
# [AttackLogger] Episodios:  15000 | Reward medio:  0.300 | Tasa éxito:  31.0% | p_attack media:  0.637 | dist media:  1.000
# [AttackLogger] Episodios:  15100 | Reward medio:  0.308 | Tasa éxito:  32.0% | p_attack media:  0.654 | dist media:  1.000
# [AttackLogger] Episodios:  15200 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.656 | dist media:  1.000
# [AttackLogger] Episodios:  15300 | Reward medio:  0.260 | Tasa éxito:  27.0% | p_attack media:  0.670 | dist media:  1.000
# [AttackLogger] Episodios:  15400 | Reward medio:  0.369 | Tasa éxito:  38.0% | p_attack media:  0.594 | dist media:  0.998
# [AttackLogger] Episodios:  15500 | Reward medio:  0.300 | Tasa éxito:  31.0% | p_attack media:  0.641 | dist media:  1.000
# [AttackLogger] Episodios:  15600 | Reward medio:  0.400 | Tasa éxito:  41.0% | p_attack media:  0.602 | dist media:  1.000
# [AttackLogger] Episodios:  15700 | Reward medio:  0.338 | Tasa éxito:  35.0% | p_attack media:  0.645 | dist media:  1.000
# [AttackLogger] Episodios:  15800 | Reward medio:  0.322 | Tasa éxito:  33.0% | p_attack media:  0.655 | dist media:  1.000
# [AttackLogger] Episodios:  15900 | Reward medio:  0.368 | Tasa éxito:  37.0% | p_attack media:  0.605 | dist media:  1.000
# [AttackLogger] Episodios:  16000 | Reward medio:  0.418 | Tasa éxito:  42.0% | p_attack media:  0.593 | dist media:  1.000
# [AttackLogger] Episodios:  16100 | Reward medio:  0.332 | Tasa éxito:  34.0% | p_attack media:  0.652 | dist media:  1.000
# [AttackLogger] Episodios:  16200 | Reward medio:  0.393 | Tasa éxito:  41.0% | p_attack media:  0.589 | dist media:  1.000
# [AttackLogger] Episodios:  16300 | Reward medio:  0.312 | Tasa éxito:  31.0% | p_attack media:  0.646 | dist media:  1.000
# [AttackLogger] Episodios:  16400 | Reward medio:  0.326 | Tasa éxito:  34.0% | p_attack media:  0.671 | dist media:  1.000
# [AttackLogger] Episodios:  16500 | Reward medio:  0.321 | Tasa éxito:  34.0% | p_attack media:  0.645 | dist media:  0.984
# [AttackLogger] Episodios:  16600 | Reward medio:  0.330 | Tasa éxito:  34.0% | p_attack media:  0.642 | dist media:  0.994
# [AttackLogger] Episodios:  16700 | Reward medio:  0.399 | Tasa éxito:  41.0% | p_attack media:  0.634 | dist media:  0.999
# [AttackLogger] Episodios:  16800 | Reward medio:  0.318 | Tasa éxito:  32.0% | p_attack media:  0.649 | dist media:  0.989
# [AttackLogger] Episodios:  16900 | Reward medio:  0.358 | Tasa éxito:  36.0% | p_attack media:  0.636 | dist media:  1.000
# [AttackLogger] Episodios:  17000 | Reward medio:  0.304 | Tasa éxito:  32.0% | p_attack media:  0.652 | dist media:  1.000
# [AttackLogger] Episodios:  17100 | Reward medio:  0.327 | Tasa éxito:  34.0% | p_attack media:  0.642 | dist media:  1.000
# [AttackLogger] Episodios:  17200 | Reward medio:  0.421 | Tasa éxito:  43.0% | p_attack media:  0.587 | dist media:  1.000
# [AttackLogger] Episodios:  17300 | Reward medio:  0.422 | Tasa éxito:  43.0% | p_attack media:  0.602 | dist media:  1.000
# [AttackLogger] Episodios:  17400 | Reward medio:  0.322 | Tasa éxito:  34.0% | p_attack media:  0.635 | dist media:  1.000
# [AttackLogger] Episodios:  17500 | Reward medio:  0.365 | Tasa éxito:  37.0% | p_attack media:  0.626 | dist media:  1.000
# [AttackLogger] Episodios:  17600 | Reward medio:  0.338 | Tasa éxito:  35.0% | p_attack media:  0.627 | dist media:  0.998
# [AttackLogger] Episodios:  17700 | Reward medio:  0.332 | Tasa éxito:  34.0% | p_attack media:  0.651 | dist media:  1.000
# [AttackLogger] Episodios:  17800 | Reward medio:  0.289 | Tasa éxito:  31.0% | p_attack media:  0.640 | dist media:  0.994
# [AttackLogger] Episodios:  17900 | Reward medio:  0.358 | Tasa éxito:  36.0% | p_attack media:  0.600 | dist media:  1.000
# [AttackLogger] Episodios:  18000 | Reward medio:  0.298 | Tasa éxito:  30.0% | p_attack media:  0.669 | dist media:  0.999
# [AttackLogger] Episodios:  18100 | Reward medio:  0.363 | Tasa éxito:  37.0% | p_attack media:  0.631 | dist media:  1.000
# [AttackLogger] Episodios:  18200 | Reward medio:  0.375 | Tasa éxito:  38.0% | p_attack media:  0.629 | dist media:  1.000
# [AttackLogger] Episodios:  18300 | Reward medio:  0.323 | Tasa éxito:  33.0% | p_attack media:  0.679 | dist media:  1.000
# [AttackLogger] Episodios:  18400 | Reward medio:  0.292 | Tasa éxito:  30.0% | p_attack media:  0.661 | dist media:  0.999
# [AttackLogger] Episodios:  18500 | Reward medio:  0.443 | Tasa éxito:  46.0% | p_attack media:  0.578 | dist media:  0.996
# [AttackLogger] Episodios:  18600 | Reward medio:  0.295 | Tasa éxito:  30.0% | p_attack media:  0.678 | dist media:  0.997
# [AttackLogger] Episodios:  18700 | Reward medio:  0.368 | Tasa éxito:  37.0% | p_attack media:  0.604 | dist media:  0.997
# [AttackLogger] Episodios:  18800 | Reward medio:  0.378 | Tasa éxito:  39.0% | p_attack media:  0.567 | dist media:  0.997
# [AttackLogger] Episodios:  18900 | Reward medio:  0.321 | Tasa éxito:  33.0% | p_attack media:  0.646 | dist media:  1.000
# [AttackLogger] Episodios:  19000 | Reward medio:  0.404 | Tasa éxito:  41.0% | p_attack media:  0.578 | dist media:  1.000
# [AttackLogger] Episodios:  19100 | Reward medio:  0.417 | Tasa éxito:  43.0% | p_attack media:  0.577 | dist media:  0.999
# [AttackLogger] Episodios:  19200 | Reward medio:  0.307 | Tasa éxito:  31.0% | p_attack media:  0.664 | dist media:  1.000
# [AttackLogger] Episodios:  19300 | Reward medio:  0.378 | Tasa éxito:  39.0% | p_attack media:  0.629 | dist media:  1.000
# [AttackLogger] Episodios:  19400 | Reward medio:  0.391 | Tasa éxito:  40.0% | p_attack media:  0.622 | dist media:  1.000
# [AttackLogger] Episodios:  19500 | Reward medio:  0.395 | Tasa éxito:  40.0% | p_attack media:  0.588 | dist media:  1.000
# [AttackLogger] Episodios:  19600 | Reward medio:  0.292 | Tasa éxito:  30.0% | p_attack media:  0.651 | dist media:  1.000
# [AttackLogger] Episodios:  19700 | Reward medio:  0.441 | Tasa éxito:  45.0% | p_attack media:  0.562 | dist media:  1.000
# [AttackLogger] Episodios:  19800 | Reward medio:  0.349 | Tasa éxito:  36.0% | p_attack media:  0.621 | dist media:  1.000
# [AttackLogger] Episodios:  19900 | Reward medio:  0.359 | Tasa éxito:  37.0% | p_attack media:  0.630 | dist media:  0.998
# [AttackLogger] Episodios:  20000 | Reward medio:  0.257 | Tasa éxito:  27.0% | p_attack media:  0.695 | dist media:  1.000

# %%
# Configuración de gráficos para visualizar los resultados
plt.style.use("seaborn-v0_8-whitegrid")

# Datos para graficar
episodes = np.array(callback_PPO.history_episodes)

# %%
print("episodes:", len(callback_PPO.history_episodes))
print("mean_reward:", len(callback_PPO.history_mean_reward))
print("mean_p_attack:", len(callback_PPO.history_mean_p_attack))
print("success_rate:", len(callback_PPO.history_success_rate))
# Out:
# episodes: 200
# mean_reward: 200
# mean_p_attack: 200
# success_rate: 200

# %%
# Gáfico de Tasa de éxito
success_rate = np.array(callback_PPO.history_success_rate) * 100

# Suavizado
window = 5
smooth_success = uniform_filter1d(success_rate, size=window)
mean = smooth_success
std = uniform_filter1d(np.abs(success_rate - mean), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Grafico de Tasa de éxito
plt.plot(episodes, mean, linewidth=2.2, color="#007acc")
plt.fill_between(
    episodes,
    mean - std,
    mean + std,
    color="#007acc",
    alpha=0.15
)
plt.title("Tasa de éxito del atacante", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Éxito (%)", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Reward medio
mean_reward = np.array(callback_PPO.history_mean_reward)

# Suavizado
window = 5
smooth_reward = uniform_filter1d(mean_reward, size=window)

# Desviación estándar local
std_reward = uniform_filter1d(np.abs(mean_reward - smooth_reward), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_reward, linewidth=2.2, color="#d35400")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_reward - std_reward,
    smooth_reward + std_reward,
    color="#d35400",
    alpha=0.15
)
plt.title("Reward medio por ventana (100 episodios)", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Reward", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Probabilidad media de ataque
mean_p_attack = np.array(callback_PPO.history_mean_p_attack)

# Suavizado
window = 5
smooth_p_attack = uniform_filter1d(mean_p_attack, size=window)

# Desviación estándar local
std_p_attack = uniform_filter1d(np.abs(mean_p_attack - smooth_p_attack), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_p_attack, linewidth=2.2, color="#8e44ad")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_p_attack - std_p_attack,
    smooth_p_attack + std_p_attack,
    color="#8e44ad",
    alpha=0.15
)
plt.title("Probabilidad media final de ataque", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("p_attack", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de PPO

# %%
# Creamos un entorno vectorizado para evaluación
eval_env = DummyVecEnv([make_env])

# Cargamos la normalización del entorno usado en entrenamiento
eval_env = VecNormalize.load("../../agents/v2/ppo_attacker_limited_multistep_vecnorm_v2.pkl", eval_env)

# Desactivamos el entrenamiento, de manera que las estadísticas de normalización no se actualicen durante la evaluación 
eval_env.training = False

# Desactivamos la normalización de recompensas para la evaluación (cuando evaluamos queremos las recompensas reales)
eval_env.norm_reward = False

# Cargamos el modelo entrenado
model = PPO.load("../../agents/v2/ppo_attacker_limited_multistep_v2")

# Evaluamos el agente PPO atacante con 300 episodios
success_rate, mean_final_p, mean_final_dist = evaluate_sac_attacker(model, eval_env, n_episodes=300)

# Mostramos los resultados finales de la evaluación
print(f"Tasa de evasión (episodio completo, PPO): {success_rate*100:.3f}%")
print(f"Probabilidad media final de ataque (PPO): {mean_final_p*100:.3f}%")
print(f"Distancia media final de la perturbación: {mean_final_dist:.3f}") # La distancia media entre x_adv y x_orig (tamaño medio de la perturbación)
# Out:
# Tasa de evasión (episodio completo, PPO): 29.333%
# Probabilidad media final de ataque (PPO): 66.665%
# Distancia media final de la perturbación: 1.000

# %%
# Muestreamos 300 ataques adversariales generados por el agente PPO multi-step
xs_orig, xs_adv, successes, mean_final_dist  = sample_adversarials_multistep(model, eval_env, n_episodes=300)

# Configuración de gráficos
plt.figure(figsize=(6, 6))

# Pintamos los ataques originales de color azul claro
plt.scatter(xs_orig[:, 0], xs_orig[:, 1], alpha=0.3, label="Original (ataque)")

# Pintamos los ataques adversariales que lograron evadir el detector de color naranja
mask_ok = successes == 1
plt.scatter(xs_adv[mask_ok, 0], xs_adv[mask_ok, 1], alpha=0.7, label="Adversarial (evade)")
plt.legend()
plt.grid(True)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Ataques adversariales aprendidos por el agente (multi-step SAC)")
plt.show()
