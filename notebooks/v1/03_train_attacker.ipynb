# %% [markdown]
# Preparación del entorno

# %%
# Instalación de librerías
# %pip install "stable-baselines3[extra]" gymnasium
# Out:
# Requirement already satisfied: gymnasium in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (1.2.2)
# Requirement already satisfied: stable-baselines3[extra] in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (2.7.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (2.2.6)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (2.9.1)
# Requirement already satisfied: cloudpickle in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: pandas in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (3.10.7)
# Requirement already satisfied: opencv-python in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (4.12.0.88)
# Requirement already satisfied: pygame in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (2.20.0)
# Requirement already satisfied: psutil in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (7.1.3)
# Requirement already satisfied: tqdm in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (14.2.0)
# Requirement already satisfied: ale-py>=0.9.0 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from stable-baselines3[extra]) (12.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: filelock in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.5)
# Requirement already satisfied: jinja2 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: packaging in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (6.33.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from rich->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from rich->stable-baselines3[extra]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: colorama in c:\users\rober\miniconda3\envs\tesis-roberto\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importación de dependencias necesarias
import numpy as np
import joblib
from envs.v1.attack_env import AttackEnv
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
import matplotlib.pyplot as plt

# %% [markdown]
# Funciones Auxiliares

# %%
# Clase callback personalizada para logear y graficar
class AttackLoggerCallback(BaseCallback): # Extiende BaseCallback de stable-baselines3

    def __init__(self, log_freq: int = 1000, verbose: int = 0): # Muestra estadísticas cada 1000 episodios y pone el nivel de verbosidad a 0 por defecto (no muestra nada)
        super().__init__(verbose) # Llamamos al constructor padre con el nivel de verbosidad
        self.log_freq = log_freq # Muestra estadísticas cada log_freq episodios
        self.episode_count = 0 # Contador de episodios completados

        # Buffers por ventana (1000 episodios)
        self.rewards_buffer = [] # Buffer para recompensas
        self.success_buffer = [] # Buffer de veces que tuvo éxito
        self.p_attack_buffer = [] # Buffer de probabilidades de que el detector detecte el ataque

        # Históricos completos para graficar
        self.history_episodes = []
        self.history_mean_reward = []
        self.history_success_rate = []
        self.history_mean_p_attack = []

    def _on_step(self) -> bool:

        # Extraemos la información relevante del entorno
        infos = self.locals["infos"] # Información devuelta por el entorno
        rewards = self.locals["rewards"] # Recompensas obtenidas
        dones = self.locals["dones"] # Si el episodio ha terminado

        # Iteramos sobre la información, recompensas y estados de finalización
        for info, r, done in zip(infos, rewards, dones):

            # Si el episodio ha terminado
            if done:
                self.episode_count += 1 #  Incrementamos el contador de episodios
                self.rewards_buffer.append(float(r)) # Guardamos la recompensa obtenida

                # Si hubo éxito en el ataque
                if "success" in info:
                    self.success_buffer.append(int(info["success"])) # Guardamos si tuvo éxito

                # Si se proporciona la probabilidad de detección del ataque
                if "p_attack" in info:
                    self.p_attack_buffer.append(float(info["p_attack"])) # Guardamos la probabilidad de detección del ataque

        # Cada log_freq episodios, mostramos las estadísticas
        if self.episode_count > 0 and self.episode_count % self.log_freq == 0:

            # Calculamos las métricas
            mean_reward = np.mean(self.rewards_buffer) if self.rewards_buffer else 0.0 # Recompensa media
            success_rate = np.mean(self.success_buffer) if self.success_buffer else 0.0 # Tasa de éxito
            mean_p_attack = np.mean(self.p_attack_buffer) if self.p_attack_buffer else 0.0 # Probabilidad media de detección del ataque

            # Guardamos las métricas en el histórico
            self.history_episodes.append(self.episode_count) # Episodios completados
            self.history_mean_reward.append(mean_reward) # Recompensa media
            self.history_success_rate.append(success_rate) # Tasa de éxito
            self.history_mean_p_attack.append(mean_p_attack) # Probabilidad media de detección del ataque

            # Mostramos las métricas por consola
            print(
                f"[AttackLogger] Episodios: {self.episode_count:6d} | "
                f"Reward medio: {mean_reward: .3f} | "
                f"Tasa éxito: {success_rate*100:5.1f}% | "
                f"p_attack media: {mean_p_attack: .3f}"
            )

            # Limpiamos los buffers para la siguiente ventana
            self.rewards_buffer.clear()
            self.success_buffer.clear()
            self.p_attack_buffer.clear()

        return True

# %%
# Función para evaluar el desempeño del atacante
def evaluate_attacker(model, env, n_episodes=1000): # Modelo entrenado, entorno y número de episodios a evaluar
    
    # Variable para recuento
    successes = 0 # Contador de éxitos
    deltas_norm = [] # Lista para guardar las normas de las perturbaciones aplicadas (cuanto se ha modificado cada muestra)
 
    # Reseteamos el entorno para obtener la observación inicial
    obs, info = env.reset() 

    # Iteramos por el número de episodios a evaluar
    for _ in range(n_episodes): 

        # Obtenemos la acción del modelo (determinística, ahora queremos el mejor ataque posible no explorar)
        action, _ = model.predict(obs, deterministic=True)

        # Ejecutamos la acción en el entorno y obtenemos los resultados
        next_obs, reward, terminated, truncated, info = env.step(action)

        # Si el ataque fue exitoso
        if info["success"] == 1:
            successes += 1 # Incrementamos el contador de éxitos

        # Calculamos la norma de la perturbación aplicada
        delta = info["x_adv"] - info["x_orig"]

        # Guardamos la norma de la perturbación
        deltas_norm.append(np.linalg.norm(delta))

        # Si el episodio ha terminado, reseteamos el entorno
        if terminated or truncated:
            obs, info = env.reset()
        # Sino, continuamos con la siguiente observación
        else:
            obs = next_obs

    # Calculamos las métricas finales
    success_rate = successes / n_episodes # Tasa de éxito, número de éxitos dividido por número de episodios
    mean_delta = float(np.mean(deltas_norm)) # Norma media de las perturbaciones aplicadas

    # Devolvemos la tasa de éxito y la norma media de las perturbaciones aplicadas  
    return success_rate, mean_delta

# %%
# Función para evaluar el desempeño del atacante aleatorio
def evaluate_random_attacker(env, n_episodes=1000): # Entorno y número de episodios a evaluar

    # Variable para recuento
    successes = 0 # Contador de éxitos
    deltas_norm = [] # Lista para guardar las normas de las perturbaciones aplicadas (cuanto se ha modificado cada muestra)

    # Reseteamos el entorno para obtener la observación inicial
    obs, info = env.reset()

    # Iteramos por el número de episodios a evaluar
    for _ in range(n_episodes):

        # Seleccionamos una acción aleatoria
        action = env.action_space.sample()

        # Ejecutamos la acción en el entorno y obtenemos los resultados
        next_obs, reward, terminated, truncated, info = env.step(action)

        # Si el ataque fue exitoso
        if info["success"] == 1:
            successes += 1 # Incrementamos el contador de éxitos

        # Calculamos la norma de la perturbación aplicada
        delta = info["x_adv"] - info["x_orig"]

        # Guardamos la norma de la perturbación
        deltas_norm.append(np.linalg.norm(delta))

        # Si el episodio ha terminado, reseteamos el entorno
        if terminated or truncated:
            obs, info = env.reset()
        # Sino, continuamos con la siguiente observación
        else:
            obs = next_obs

    # Calculamos las métricas finales
    success_rate = successes / n_episodes
    mean_delta = float(np.mean(deltas_norm))

    # Devolvemos la tasa de éxito y la norma media de las perturbaciones aplicadas  
    return success_rate, mean_delta

# %%
# Función para muestrear ataques adversariales generados por el agente
def sample_adversarials(model, env, n_samples=200): # Entorno y número de muestras a generar

    # Listas para guardar los datos muestreados
    xs_orig = []
    xs_adv = []
    successes = []

    # Reseteamos el entorno para obtener la observación inicial
    obs, info = env.reset()

    # Iteramos para muestrear el número de ataques adversariales deseados
    for _ in range(n_samples):

        # Obtenemos la acción del modelo (determinística)
        action, _ = model.predict(obs, deterministic=True)

        # Ejecutamos la acción en el entorno y obtenemos los resultados
        next_obs, reward, terminated, truncated, info = env.step(action)

        # Guardamos los datos relevantes de la información proporcionada por el entorno
        xs_orig.append(info["x_orig"])
        xs_adv.append(info["x_adv"])
        successes.append(info["success"])

        # Reseteamos el entorno
        obs, info = env.reset()

    # Devolvemos los arrays de datos muestreados
    return np.array(xs_orig), np.array(xs_adv), np.array(successes)

# %% [markdown]
# Creación del área de trabajo

# %%
# Carga del dataset
data = np.load("../../data/v1/synthetic_2d.npz")
X_train, X_test = data["X_train"], data["X_test"]
y_train, y_test = data["y_train"], data["y_test"]

# Cargamos solo muestras de ataque para el entorno
attack_mask = y_train == 1 # Crea un array booleano a true para muestras de ataque
attack_samples = X_train[attack_mask] # Nos quedamos solo con las muestras de ataque

# Imprimimos la forma de las muestras de ataque
print("Attack samples:", attack_samples.shape)

# Carga del modelo clasificador
clf = joblib.load("../../classifiers/v1/logreg_synthetic_2d.joblib")
# Out:
# Attack samples: (800, 2)

# %%
# Creación del entorno
env = AttackEnv(
    attack_samples=attack_samples, # Lista de todas las muestras de ataque
    clf=clf, # Modelo clasificador
    threshold=0.5, # A partid de de esta probabilidad se considera que es ataque
    epsilon=0.5, # Distancia máxima que el agente puede mofificar el punto original
    penalty=0.05, # Penalización por moverse mucho
)

# %% [markdown]
# Entrenamiento del agente PPO

# %%
# Constucción y entrenamiento del agente PPO (RL)
policy_kwargs = dict(net_arch=[64, 64]) # Arquitectura de la red neuronal, dos capas ocultas de 64 neuronas cada una

model = PPO(
    "MlpPolicy",
    env, # Ligamos el modelo con el entorno
    verbose=0, # Indica imprimir información báscica del entrenamiento (1) o no (0)
    policy_kwargs=policy_kwargs, # Le pasamos la arquiectura definida para la red neuronal
    n_steps=2048, # Número de pasos a ejecutar antes de cada actualización de política
    batch_size=64,  # Los grupos en los que se divide cada actualización
    learning_rate=3e-4, # Tasa de aprendizaje, qué tanto se actualizan los pesos de la red neuronal en cada paso
)

# Creación del callback personalizado para logging
callback = AttackLoggerCallback(log_freq=1000)

# Entrenamiento del agente de 100,000 pasos y uso del callback para logging
model.learn(total_timesteps=100_000, callback=callback)

# Guardado del modelo entrenado
model.save("../../agents/v1/ppo_attacker_synthetic_2d")
# Out:
# [AttackLogger] Episodios:   1000 | Reward medio:  0.001 | Tasa éxito:   2.0% | p_attack media:  0.966
# [AttackLogger] Episodios:   2000 | Reward medio:  0.001 | Tasa éxito:   2.0% | p_attack media:  0.968
# [AttackLogger] Episodios:   3000 | Reward medio: -0.002 | Tasa éxito:   1.6% | p_attack media:  0.968
# [AttackLogger] Episodios:   4000 | Reward medio: -0.001 | Tasa éxito:   1.7% | p_attack media:  0.964
# [AttackLogger] Episodios:   5000 | Reward medio:  0.007 | Tasa éxito:   2.6% | p_attack media:  0.960
# [AttackLogger] Episodios:   6000 | Reward medio:  0.007 | Tasa éxito:   2.5% | p_attack media:  0.964
# [AttackLogger] Episodios:   7000 | Reward medio:  0.007 | Tasa éxito:   2.5% | p_attack media:  0.954
# [AttackLogger] Episodios:   8000 | Reward medio:  0.014 | Tasa éxito:   3.2% | p_attack media:  0.952
# [AttackLogger] Episodios:   9000 | Reward medio:  0.014 | Tasa éxito:   3.2% | p_attack media:  0.953
# [AttackLogger] Episodios:  10000 | Reward medio:  0.009 | Tasa éxito:   2.7% | p_attack media:  0.957
# [AttackLogger] Episodios:  11000 | Reward medio:  0.014 | Tasa éxito:   3.2% | p_attack media:  0.950
# [AttackLogger] Episodios:  12000 | Reward medio:  0.028 | Tasa éxito:   4.5% | p_attack media:  0.941
# [AttackLogger] Episodios:  13000 | Reward medio:  0.013 | Tasa éxito:   3.0% | p_attack media:  0.950
# [AttackLogger] Episodios:  14000 | Reward medio:  0.024 | Tasa éxito:   4.2% | p_attack media:  0.941
# [AttackLogger] Episodios:  15000 | Reward medio:  0.039 | Tasa éxito:   5.7% | p_attack media:  0.928
# [AttackLogger] Episodios:  16000 | Reward medio:  0.025 | Tasa éxito:   4.3% | p_attack media:  0.939
# [AttackLogger] Episodios:  17000 | Reward medio:  0.022 | Tasa éxito:   3.9% | p_attack media:  0.939
# [AttackLogger] Episodios:  18000 | Reward medio:  0.032 | Tasa éxito:   4.9% | p_attack media:  0.931
# [AttackLogger] Episodios:  19000 | Reward medio:  0.041 | Tasa éxito:   5.8% | p_attack media:  0.928
# [AttackLogger] Episodios:  20000 | Reward medio:  0.030 | Tasa éxito:   4.7% | p_attack media:  0.932
# [AttackLogger] Episodios:  21000 | Reward medio:  0.035 | Tasa éxito:   5.2% | p_attack media:  0.931
# [AttackLogger] Episodios:  22000 | Reward medio:  0.034 | Tasa éxito:   5.1% | p_attack media:  0.930
# [AttackLogger] Episodios:  23000 | Reward medio:  0.041 | Tasa éxito:   5.8% | p_attack media:  0.920
# [AttackLogger] Episodios:  24000 | Reward medio:  0.031 | Tasa éxito:   4.8% | p_attack media:  0.936
# [AttackLogger] Episodios:  25000 | Reward medio:  0.045 | Tasa éxito:   6.2% | p_attack media:  0.922
# [AttackLogger] Episodios:  26000 | Reward medio:  0.048 | Tasa éxito:   6.5% | p_attack media:  0.921
# [AttackLogger] Episodios:  27000 | Reward medio:  0.054 | Tasa éxito:   7.1% | p_attack media:  0.910
# [AttackLogger] Episodios:  28000 | Reward medio:  0.046 | Tasa éxito:   6.3% | p_attack media:  0.917
# [AttackLogger] Episodios:  29000 | Reward medio:  0.036 | Tasa éxito:   5.3% | p_attack media:  0.925
# [AttackLogger] Episodios:  30000 | Reward medio:  0.033 | Tasa éxito:   5.0% | p_attack media:  0.923
# [AttackLogger] Episodios:  31000 | Reward medio:  0.047 | Tasa éxito:   6.4% | p_attack media:  0.917
# [AttackLogger] Episodios:  32000 | Reward medio:  0.054 | Tasa éxito:   7.1% | p_attack media:  0.910
# [AttackLogger] Episodios:  33000 | Reward medio:  0.066 | Tasa éxito:   8.3% | p_attack media:  0.904
# [AttackLogger] Episodios:  34000 | Reward medio:  0.052 | Tasa éxito:   6.9% | p_attack media:  0.905
# [AttackLogger] Episodios:  35000 | Reward medio:  0.049 | Tasa éxito:   6.6% | p_attack media:  0.911
# [AttackLogger] Episodios:  36000 | Reward medio:  0.049 | Tasa éxito:   6.5% | p_attack media:  0.917
# [AttackLogger] Episodios:  37000 | Reward medio:  0.047 | Tasa éxito:   6.3% | p_attack media:  0.914
# [AttackLogger] Episodios:  38000 | Reward medio:  0.041 | Tasa éxito:   5.7% | p_attack media:  0.918
# [AttackLogger] Episodios:  39000 | Reward medio:  0.054 | Tasa éxito:   7.1% | p_attack media:  0.913
# [AttackLogger] Episodios:  40000 | Reward medio:  0.052 | Tasa éxito:   6.8% | p_attack media:  0.911
# [AttackLogger] Episodios:  41000 | Reward medio:  0.062 | Tasa éxito:   7.9% | p_attack media:  0.903
# [AttackLogger] Episodios:  42000 | Reward medio:  0.044 | Tasa éxito:   6.1% | p_attack media:  0.910
# [AttackLogger] Episodios:  43000 | Reward medio:  0.045 | Tasa éxito:   6.1% | p_attack media:  0.916
# [AttackLogger] Episodios:  44000 | Reward medio:  0.060 | Tasa éxito:   7.6% | p_attack media:  0.904
# [AttackLogger] Episodios:  45000 | Reward medio:  0.054 | Tasa éxito:   7.0% | p_attack media:  0.914
# [AttackLogger] Episodios:  46000 | Reward medio:  0.064 | Tasa éxito:   8.0% | p_attack media:  0.902
# [AttackLogger] Episodios:  47000 | Reward medio:  0.056 | Tasa éxito:   7.2% | p_attack media:  0.909
# [AttackLogger] Episodios:  48000 | Reward medio:  0.044 | Tasa éxito:   6.0% | p_attack media:  0.918
# [AttackLogger] Episodios:  49000 | Reward medio:  0.054 | Tasa éxito:   7.0% | p_attack media:  0.905
# [AttackLogger] Episodios:  50000 | Reward medio:  0.049 | Tasa éxito:   6.5% | p_attack media:  0.913
# [AttackLogger] Episodios:  51000 | Reward medio:  0.048 | Tasa éxito:   6.4% | p_attack media:  0.910
# [AttackLogger] Episodios:  52000 | Reward medio:  0.048 | Tasa éxito:   6.4% | p_attack media:  0.911
# [AttackLogger] Episodios:  53000 | Reward medio:  0.056 | Tasa éxito:   7.2% | p_attack media:  0.906
# [AttackLogger] Episodios:  54000 | Reward medio:  0.052 | Tasa éxito:   6.7% | p_attack media:  0.915
# [AttackLogger] Episodios:  55000 | Reward medio:  0.043 | Tasa éxito:   5.9% | p_attack media:  0.912
# [AttackLogger] Episodios:  56000 | Reward medio:  0.044 | Tasa éxito:   5.9% | p_attack media:  0.916
# [AttackLogger] Episodios:  57000 | Reward medio:  0.040 | Tasa éxito:   5.6% | p_attack media:  0.910
# [AttackLogger] Episodios:  58000 | Reward medio:  0.054 | Tasa éxito:   7.0% | p_attack media:  0.908
# [AttackLogger] Episodios:  59000 | Reward medio:  0.063 | Tasa éxito:   7.8% | p_attack media:  0.899
# [AttackLogger] Episodios:  60000 | Reward medio:  0.053 | Tasa éxito:   6.8% | p_attack media:  0.907
# [AttackLogger] Episodios:  61000 | Reward medio:  0.062 | Tasa éxito:   7.7% | p_attack media:  0.904
# [AttackLogger] Episodios:  62000 | Reward medio:  0.048 | Tasa éxito:   6.3% | p_attack media:  0.907
# [AttackLogger] Episodios:  63000 | Reward medio:  0.057 | Tasa éxito:   7.2% | p_attack media:  0.907
# [AttackLogger] Episodios:  64000 | Reward medio:  0.045 | Tasa éxito:   6.0% | p_attack media:  0.917
# [AttackLogger] Episodios:  65000 | Reward medio:  0.052 | Tasa éxito:   6.7% | p_attack media:  0.910
# [AttackLogger] Episodios:  66000 | Reward medio:  0.050 | Tasa éxito:   6.4% | p_attack media:  0.918
# [AttackLogger] Episodios:  67000 | Reward medio:  0.050 | Tasa éxito:   6.4% | p_attack media:  0.916
# [AttackLogger] Episodios:  68000 | Reward medio:  0.059 | Tasa éxito:   7.3% | p_attack media:  0.904
# [AttackLogger] Episodios:  69000 | Reward medio:  0.052 | Tasa éxito:   6.6% | p_attack media:  0.918
# [AttackLogger] Episodios:  70000 | Reward medio:  0.059 | Tasa éxito:   7.3% | p_attack media:  0.909
# [AttackLogger] Episodios:  71000 | Reward medio:  0.057 | Tasa éxito:   7.1% | p_attack media:  0.907
# [AttackLogger] Episodios:  72000 | Reward medio:  0.047 | Tasa éxito:   6.1% | p_attack media:  0.915
# [AttackLogger] Episodios:  73000 | Reward medio:  0.054 | Tasa éxito:   6.8% | p_attack media:  0.908
# [AttackLogger] Episodios:  74000 | Reward medio:  0.045 | Tasa éxito:   5.9% | p_attack media:  0.913
# [AttackLogger] Episodios:  75000 | Reward medio:  0.053 | Tasa éxito:   6.7% | p_attack media:  0.914
# [AttackLogger] Episodios:  76000 | Reward medio:  0.050 | Tasa éxito:   6.4% | p_attack media:  0.910
# [AttackLogger] Episodios:  77000 | Reward medio:  0.066 | Tasa éxito:   8.0% | p_attack media:  0.903
# [AttackLogger] Episodios:  78000 | Reward medio:  0.044 | Tasa éxito:   5.7% | p_attack media:  0.912
# [AttackLogger] Episodios:  79000 | Reward medio:  0.055 | Tasa éxito:   6.9% | p_attack media:  0.906
# [AttackLogger] Episodios:  80000 | Reward medio:  0.044 | Tasa éxito:   5.7% | p_attack media:  0.918
# [AttackLogger] Episodios:  81000 | Reward medio:  0.056 | Tasa éxito:   7.0% | p_attack media:  0.900
# [AttackLogger] Episodios:  82000 | Reward medio:  0.065 | Tasa éxito:   7.9% | p_attack media:  0.898
# [AttackLogger] Episodios:  83000 | Reward medio:  0.051 | Tasa éxito:   6.4% | p_attack media:  0.915
# [AttackLogger] Episodios:  84000 | Reward medio:  0.061 | Tasa éxito:   7.5% | p_attack media:  0.899
# [AttackLogger] Episodios:  85000 | Reward medio:  0.059 | Tasa éxito:   7.2% | p_attack media:  0.897
# [AttackLogger] Episodios:  86000 | Reward medio:  0.064 | Tasa éxito:   7.7% | p_attack media:  0.900
# [AttackLogger] Episodios:  87000 | Reward medio:  0.044 | Tasa éxito:   5.6% | p_attack media:  0.922
# [AttackLogger] Episodios:  88000 | Reward medio:  0.053 | Tasa éxito:   6.5% | p_attack media:  0.913
# [AttackLogger] Episodios:  89000 | Reward medio:  0.060 | Tasa éxito:   7.3% | p_attack media:  0.900
# [AttackLogger] Episodios:  90000 | Reward medio:  0.059 | Tasa éxito:   7.2% | p_attack media:  0.907
# [AttackLogger] Episodios:  91000 | Reward medio:  0.057 | Tasa éxito:   7.0% | p_attack media:  0.906
# [AttackLogger] Episodios:  92000 | Reward medio:  0.059 | Tasa éxito:   7.2% | p_attack media:  0.905
# [AttackLogger] Episodios:  93000 | Reward medio:  0.043 | Tasa éxito:   5.5% | p_attack media:  0.930
# [AttackLogger] Episodios:  94000 | Reward medio:  0.047 | Tasa éxito:   6.0% | p_attack media:  0.913
# [AttackLogger] Episodios:  95000 | Reward medio:  0.051 | Tasa éxito:   6.3% | p_attack media:  0.914
# [AttackLogger] Episodios:  96000 | Reward medio:  0.061 | Tasa éxito:   7.4% | p_attack media:  0.907
# [AttackLogger] Episodios:  97000 | Reward medio:  0.059 | Tasa éxito:   7.1% | p_attack media:  0.910
# [AttackLogger] Episodios:  98000 | Reward medio:  0.053 | Tasa éxito:   6.6% | p_attack media:  0.910
# [AttackLogger] Episodios:  99000 | Reward medio:  0.055 | Tasa éxito:   6.7% | p_attack media:  0.906
# [AttackLogger] Episodios: 100000 | Reward medio:  0.059 | Tasa éxito:   7.1% | p_attack media:  0.905
# c:\Users\rober\miniconda3\envs\tesis-roberto\Lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path '..\..\agents\v1' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# Gráficas

# %%
# Obtenemos los datos del callback
episodes = np.array(callback.history_episodes) # Número de episodios
success_rate = np.array(callback.history_success_rate) * 100  # Porcentaje de éxito

# Tamaño de la ventana para la media móvil (suavizado)
window = 20

# Configuración de los elementos para la media móvil
kernel = np.ones(window) / window # Kernel para la media móvil (calculado como la media de los últimos 'window' puntos)
half = window // 2 # Mitad de la ventana
padded = np.pad(success_rate, (half, window - 1 - half), mode="edge") # Padding para los bordes (replicando los valores de los extremos)
success_smooth = np.convolve(padded, kernel, mode="valid") # Convolución "limpia", corregimos los bordes
episodes_smooth = episodes  # La gráfica suavizada tendrá la misma longitud que los datos originales

# Configuración de la figura
plt.figure(figsize=(8, 5), dpi=120)

# Línea original (sin suavizar), semitransparente
plt.plot(
    episodes,
    success_rate,
    alpha=0.25,
    linewidth=1,
    label="Tasa de éxito (sin suavizar)",
)

# Línea suavizada con media móvil
plt.plot(
    episodes_smooth,
    success_smooth,
    linewidth=2.0,
    label=f"Media móvil ({window} puntos)",
)

# Etiquetas y estilo
plt.xlabel("Episodios", fontsize=11)
plt.ylabel("Tasa de éxito (%)", fontsize=11)
plt.title("Evolución de la tasa de éxito del atacante", fontsize=13)
plt.grid(True, alpha=0.2)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluación

# %%
# Cargamos el modelo entrenado
model = PPO.load("../../agents/v1/ppo_attacker_synthetic_2d")

# Evaluamos el atacante entrenado con 2000 episodios y el modelo entrenado
success_rate, mean_delta = evaluate_attacker(model, env, n_episodes=2000)

# Mostramos los resultados de la evaluación final
print(f"Tasa de evasión: {success_rate*100:.3f}%")
print(f"Norma media de la perturbación: {mean_delta:.3f}")
# Out:
# Tasa de evasión: 8.000%
# Norma media de la perturbación: 0.309

# %%
# Evaluamos un atacante aleatorio con 2000 episodios
rand_success, rand_delta = evaluate_random_attacker(env, n_episodes=2000)

# Mostramos los resultados de la evaluación final
print(f"[Random] Tasa de evasión: {rand_success*100:.3f}%")
print(f"[Random] Norma media de la perturbación: {rand_delta:.3f}")
# Out:
# [Random] Tasa de evasión: 1.050%
# [Random] Norma media de la perturbación: 0.377

# %% [markdown]
# Conclusiones

# %%
# Muestreamos 300 ataques adversariales generados por el agente entrenado
xs_orig, xs_adv, successes = sample_adversarials(model, env, n_samples=300)

# Configuración de la gráfica
plt.figure(figsize=(6, 6))

# Pintamos los ataques originales de color azul claro
plt.scatter(xs_orig[:, 0], xs_orig[:, 1], alpha=0.3, label="Original (ataque)")

# Pintamos los ataques adversariales que lograron evadir el detector de color naranja
mask_ok = successes == 1
plt.scatter(xs_adv[mask_ok, 0], xs_adv[mask_ok, 1], alpha=0.7, label="Adversarial (evade)")
plt.legend()
plt.grid(True)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Ataques adversariales aprendidos por el agente")
plt.show()

# %% [markdown]
# Conclusiones
#
# - Están claramente desplazados hacia la región de tráfico normal
#
# - No se van demasiado lejos: usa perturbaciones pequeñas, significa que el agente NO hace cambios absurdos, sino justo los necesarios para engañar al clasificador.
#
# - Están BIEN agrupados: No están dispersos por el plano a lo random. Se concentran en la región más baja del riesgo, lo que indica política aprendida basada en gradiente, no ruido.
#
# - Los evade justo justo en los puntos donde la frontera entre normal/ataque era más cercana: Esto es EXACTAMENTE comportamiento adversarial: empujar la muestra hacia el lado “normal” más cercano, de la forma más eficiente posible.
