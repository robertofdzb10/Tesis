# %% [markdown]
# Preparación del entorno

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from envs.v1.multi_step_limited_attack_env import AttackEnvLimitedMultiStep
from stable_baselines3.common.callbacks import BaseCallback
import matplotlib.pyplot as plt
import numpy as np
import joblib
from stable_baselines3 import SAC
from stable_baselines3 import PPO
from scipy.ndimage import uniform_filter1d

# %% [markdown]
# Funciones Auxiliares

# %%
# Clase callback personalizada para logear y graficar
class AttackLoggerCallback(BaseCallback): # Extiende BaseCallback de stable-baselines3

    def __init__(self, log_freq: int = 1000, verbose: int = 0): # Muestra estadísticas cada 1000 episodios y pone el nivel de verbosidad a 0 por defecto (no muestra nada)
        super().__init__(verbose) # Llamamos al constructor padre con el nivel de verbosidad
        self.log_freq = log_freq # Muestra estadísticas cada log_freq episodios
        self.episode_count = 0 # Contador de episodios completados

        # Buffers por ventana (1000 episodios)
        self.rewards_buffer = [] # Buffer para recompensas
        self.success_buffer = [] # Buffer de veces que tuvo éxito
        self.p_attack_buffer = [] # Buffer de probabilidades de que el detector detecte el ataque
        self.dist_buffer = [] # Buffer de distancias entre x_adv y x_orig (tamaño de la perturbación)

        # Históricos completos para graficar
        self.history_episodes = []
        self.history_mean_reward = []
        self.history_success_rate = []
        self.history_mean_p_attack = []
        self.history_mean_dist = [] # Historial de distancia media por ventana

    def _on_step(self) -> bool:

        # Extraemos la información relevante del entorno
        infos = self.locals["infos"] # Información devuelta por el entorno
        rewards = self.locals["rewards"] # Recompensas obtenidas
        dones = self.locals["dones"] # Si el episodio ha terminado

        # Iteramos sobre la información, recompensas y estados de finalización
        for info, r, done in zip(infos, rewards, dones):

            # Si el episodio ha terminado
            if done:
                self.episode_count += 1 #  Incrementamos el contador de episodios
                self.rewards_buffer.append(float(r)) # Guardamos la recompensa obtenida

                # Si hubo éxito en el ataque
                if "success" in info:
                    self.success_buffer.append(int(info["success"])) # Guardamos si tuvo éxito

                # Si se proporciona la probabilidad de detección del ataque
                if "p_attack" in info:
                    self.p_attack_buffer.append(float(info["p_attack"])) # Guardamos la probabilidad de detección del ataque

                # Si se proporciona la distancia entre x_adv y x_orig
                if "dist" in info:
                    self.dist_buffer.append(float(info["dist"])) # Guardamos la distancia (magnitud de la perturbación)

                # Cada log_freq episodios, mostramos las estadísticas
                if self.episode_count > 0 and self.episode_count % self.log_freq == 0:

                    # Calculamos las métricas
                    mean_reward = np.mean(self.rewards_buffer) if self.rewards_buffer else 0.0 # Recompensa media
                    success_rate = np.mean(self.success_buffer) if self.success_buffer else 0.0 # Tasa de éxito
                    mean_p_attack = np.mean(self.p_attack_buffer) if self.p_attack_buffer else 0.0 # Probabilidad media de detección del ataque
                    mean_dist = np.mean(self.dist_buffer) if self.dist_buffer else 0.0 # Distancia media (tamaño medio de la perturbación)

                    # Guardamos las métricas en el histórico
                    self.history_episodes.append(self.episode_count) # Episodios completados
                    self.history_mean_reward.append(mean_reward) # Recompensa media
                    self.history_success_rate.append(success_rate) # Tasa de éxito
                    self.history_mean_p_attack.append(mean_p_attack) # Probabilidad media de detección del ataque
                    self.history_mean_dist.append(mean_dist) # Distancia media de la perturbación

                    # Mostramos las métricas por consola
                    print(
                        f"[AttackLogger] Episodios: {self.episode_count:6d} | "
                        f"Reward medio: {mean_reward: .3f} | "
                        f"Tasa éxito: {success_rate*100:5.1f}% | "
                        f"p_attack media: {mean_p_attack: .3f} | "
                        f"dist media: {mean_dist: .3f}"
                    )

                    # Limpiamos los buffers para la siguiente ventana
                    self.rewards_buffer.clear()
                    self.success_buffer.clear()
                    self.p_attack_buffer.clear()
                    self.dist_buffer.clear()

        return True

# %%
# Función para evaluar el agente SAC atacante
def evaluate_sac_attacker(model, env, n_episodes=500): # Evalúa el agente en el entorno dado durante n_episodes episodios
    
    # Variables para recuento
    successes = 0 # Contador de episodios exitosos
    total_steps = 0 # Contador de pasos totales
    final_p_attacks = [] # Lista para almacenar las probabilidades de que el ataque modificado sea detectado como ataque
    final_dists = [] # Lista para almacenar la distancia final entre x_adv y x_orig (tamaño de la perturbación)

    # Reseteamos el entorno
    obs = env.reset()

    # Iteramos por el numero de episodios a evaluar
    for _ in range(n_episodes):

        # Variables de control de finalización del episodio
        done = False
        truncated = False

        # Mientras no se termine el episodio
        while not (done or truncated):

            # Obtenemos la acción del modelo (determinística, ahora queremos el mejor ataque posible no explorar)
            action, _ = model.predict(obs, deterministic=True)

            # Ejecutamos la acción en el entorno y obtenemos los resultados
            obs, reward, done, info = env.step(action)

            # Cogemos el primer diccionario de info (entorno vectorizado, solo hay uno)
            info0 = info[0]

            # Parche para gym
            truncated = info0.get("terminal_observation") is not None if False else False  

            # Incrementamos el contador de pasos
            total_steps += 1

            # Si el valor de step_count es igual a max_steps del entorno
            if info0.get("step_count", 0) == env.get_attr("max_steps")[0]: 

                # Si el detector no detecta el ataque (pred = 0)
                if info0["pred"] == 0: 
                    successes += 1 # Incrementamos el contador de éxitos

                # Guardamos la probabilidad de que el defensor detecte el ataque modificado por el agente como ataque
                final_p_attacks.append(info0["p_attack"])

                # Guardamos la distancia final entre x_adv y x_orig
                if "dist" in info0:
                    final_dists.append(info0["dist"])

        # Reseteamos el entorno para el siguiente episodio
        obs = env.reset()

    # Calculamos las métricas finales
    success_rate = successes / n_episodes # Tasa de éxito, número de episodios exitosos dividido por el total de episodios
    mean_final_p = float(np.mean(final_p_attacks)) if final_p_attacks else None # Probabilidad media final de ataque
    mean_final_dist = float(np.mean(final_dists)) if final_dists else None # Distancia media final de la perturbación

    # Devolvemos las métricas
    return success_rate, mean_final_p, mean_final_dist

# %%
# Función para muestrear ataques adversariales completos (multi-step)
def sample_adversarials_multistep(model, env, n_episodes=200): # Agente SAC, entorno de ataque multi-step, número de episodios a muestrear

    # Listas para almacenar los ataques originales, finales y éxitos
    xs_orig = []
    xs_final = []
    successes = []
    dists = []  # Lista para almacenar la distancia final entre x_adv y x_orig

    # Reseteamos el entorno para el primer episodio
    obs = env.reset()

    # Obtenemos el número máximo de pasos por episodio del entorno
    max_steps = env.get_attr("max_steps")[0]

    # Iteramos por el número de episodios a muestrear
    for _ in range(n_episodes):

        # Variables de control de finalización del episodio
        done = False
        truncated = False
        
        # Variable para almacenar el ataque original del episodio
        x_orig_ep = None

        # Mientras no se termine el episodio
        while not (done or truncated):

            # Obtenemos la acción del agente (determinística)
            action, _ = model.predict(obs, deterministic=True)

            # Ejecutamos la acción en el entorno y obtenemos los resultados
            obs, rewards, dones, infos = env.step(action)

            # Cogemos la información del primer entorno (vectorizado, solo hay uno)
            info0 = infos[0]
            done = dones[0]

            # Guardamos el ataque original (es el del primer paso del episodio)
            if x_orig_ep is None and "x_orig" in info0:
                x_orig_ep = info0["x_orig"]

            # Detectar último paso del episodio
            step_count = info0.get("step_count", 0)
            is_last = (step_count == max_steps) or done

            # Si es el último paso del episodio
            if is_last:
                
                # Guardamos el ataque adversarial final
                x_adv_final = info0["x_adv"]

                # Guardamos si el ataque logró evadir el detector (pred = 0)
                pred_final = info0["pred"]  # 0 = normal, 1 = ataque

                # Almacenamos los resultados
                xs_orig.append(x_orig_ep)
                xs_final.append(x_adv_final)
                successes.append(1 if pred_final == 0 else 0)

                # Guardamos la distancia final si está disponible
                if "dist" in info0:
                    dists.append(info0["dist"])

                break

        # Siguiente episodio
        obs = env.reset()

    # Devolvemos los ataques originales, finales, éxitos y distancias como arrays de numpy
    return np.array(xs_orig), np.array(xs_final), np.array(successes), np.array(dists)

# %% [markdown]
# Creación del área de trabajo

# %%
# Carga del dataset
data = np.load("../../data/v1/synthetic_2d.npz")
X_train, X_test = data["X_train"], data["X_test"]
y_train, y_test = data["y_train"], data["y_test"]

# Cargamos solo muestras de ataque para el entorno
attack_mask = y_train == 1 # Crea un array booleano a true para muestras de ataque
attack_samples = X_train[attack_mask] # Nos quedamos solo con las muestras de ataque

# Carga del modelo clasificador
clf = joblib.load("../../classifiers/v1/logreg_synthetic_2d.joblib")

# Imprimimos la forma de las muestras de ataque
print("Attack samples:", attack_samples.shape)
# Out:
# Attack samples: (800, 2)

# %%
# Función para crear el entorno
def make_env():
    return AttackEnvLimitedMultiStep(
        attack_samples=attack_samples, # Lista de todas las muestras de ataque
        clf=clf, # Modelo clasificador
        threshold=0.5, # A partid de de esta probabilidad se considera que es ataque
        epsilon=0.7,   # Distancia máxima que el agente puede mofificar el punto original, aumentamos un poco
        penalty=0.01,  # Penalización suave por tamaño de la perturbación
        max_steps=5,   # 5 movimientos por ataque
    )

# Creamos el entorno vectorizado
venv = DummyVecEnv([make_env])

# Normalizamos las observaciones del entorno    
venv = VecNormalize(venv, norm_obs=True, norm_reward=False) # SAC trabaja mejor con observaciones normalizadas (entre 0 y 1)

# %% [markdown]
# Entrenamiento del agente SAC

# %%
# Architectura de la red neuronal del actor y crítico
policy_kwargs = dict(net_arch=[256, 256])

model = SAC(
    "MlpPolicy", # Redes totamente conectadas (MLP)
    venv, # Entorno vectorizado y normalizado
    verbose=0, # No muestra información durante el entrenamiento
    policy_kwargs=policy_kwargs, # Arquitectura de la red neuronal
    buffer_size=200_000, # SAC es off-policy y usa un buffer de replay para almacenar experiencias pasadas y aprender de ellas, cada train_freq aprende batch_size pasos aleatorios del buffer
    learning_rate=3e-4, # Tasa de aprendizaje, qué tanto se actualizan los pesos de la red neuronal en cada paso
    batch_size=256, # Los grupos en los que se divide cada actualización
    tau=0.02, # Velocidad de actualización de la red objetivo (Como el critico se actualiza en función del actor, valor pequeno significa actualizaciones lentas)(Actor decide que acciones tomar, critico evalua esas accionees)
    train_freq=1, # Cada cuántos pasos de entorno se realiza una actualización del modelo
    gradient_steps=1, # Número de actualizaciones del modelo por cada paso de entorno
)

# Creación del callback personalizado para logging
callback = AttackLoggerCallback(log_freq=100)

# Entrenamiento del agente SAC con 10,000 timesteps y el callback
model.learn(total_timesteps=100_000, callback=callback)

# Guardamos el modelo entrenado y el entorno normalizado (SAC aprendio de un entorno normalizado, lo necesita para predecir)
model.save("../../agents/v1/sac_attacker_limited_multistep")
venv.save("../../agents/v1/sac_attacker_limited_multistep_vecnorm.pkl")
# Out:
# [AttackLogger] Episodios:    100 | Reward medio:  0.084 | Tasa éxito:   7.0% | p_attack media:  0.926 | dist media:  0.796
# [AttackLogger] Episodios:    200 | Reward medio:  0.063 | Tasa éxito:   6.0% | p_attack media:  0.940 | dist media:  0.857
# [AttackLogger] Episodios:    300 | Reward medio:  0.083 | Tasa éxito:   8.0% | p_attack media:  0.901 | dist media:  0.873
# [AttackLogger] Episodios:    400 | Reward medio:  0.105 | Tasa éxito:  10.0% | p_attack media:  0.880 | dist media:  0.898
# [AttackLogger] Episodios:    500 | Reward medio:  0.132 | Tasa éxito:  13.0% | p_attack media:  0.845 | dist media:  0.923
# [AttackLogger] Episodios:    600 | Reward medio:  0.116 | Tasa éxito:  11.0% | p_attack media:  0.885 | dist media:  0.921
# [AttackLogger] Episodios:    700 | Reward medio:  0.123 | Tasa éxito:  12.0% | p_attack media:  0.855 | dist media:  0.965
# [AttackLogger] Episodios:    800 | Reward medio:  0.108 | Tasa éxito:  11.0% | p_attack media:  0.876 | dist media:  0.979
# [AttackLogger] Episodios:    900 | Reward medio:  0.177 | Tasa éxito:  17.0% | p_attack media:  0.835 | dist media:  0.976
# [AttackLogger] Episodios:   1000 | Reward medio:  0.071 | Tasa éxito:   8.0% | p_attack media:  0.870 | dist media:  0.989
# [AttackLogger] Episodios:   1100 | Reward medio:  0.074 | Tasa éxito:   8.0% | p_attack media:  0.902 | dist media:  0.993
# [AttackLogger] Episodios:   1200 | Reward medio:  0.185 | Tasa éxito:  18.0% | p_attack media:  0.784 | dist media:  0.996
# [AttackLogger] Episodios:   1300 | Reward medio:  0.146 | Tasa éxito:  15.0% | p_attack media:  0.840 | dist media:  0.995
# [AttackLogger] Episodios:   1400 | Reward medio:  0.143 | Tasa éxito:  14.0% | p_attack media:  0.809 | dist media:  0.998
# [AttackLogger] Episodios:   1500 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.852 | dist media:  1.000
# [AttackLogger] Episodios:   1600 | Reward medio:  0.132 | Tasa éxito:  13.0% | p_attack media:  0.841 | dist media:  0.999
# [AttackLogger] Episodios:   1700 | Reward medio:  0.104 | Tasa éxito:  11.0% | p_attack media:  0.860 | dist media:  0.999
# [AttackLogger] Episodios:   1800 | Reward medio:  0.104 | Tasa éxito:  11.0% | p_attack media:  0.846 | dist media:  1.000
# [AttackLogger] Episodios:   1900 | Reward medio:  0.126 | Tasa éxito:  13.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:   2000 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.847 | dist media:  0.999
# [AttackLogger] Episodios:   2100 | Reward medio:  0.066 | Tasa éxito:   7.0% | p_attack media:  0.875 | dist media:  1.000
# [AttackLogger] Episodios:   2200 | Reward medio:  0.067 | Tasa éxito:   7.0% | p_attack media:  0.887 | dist media:  1.000
# [AttackLogger] Episodios:   2300 | Reward medio:  0.132 | Tasa éxito:  14.0% | p_attack media:  0.819 | dist media:  1.000
# [AttackLogger] Episodios:   2400 | Reward medio:  0.135 | Tasa éxito:  14.0% | p_attack media:  0.849 | dist media:  0.999
# [AttackLogger] Episodios:   2500 | Reward medio:  0.144 | Tasa éxito:  15.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:   2600 | Reward medio:  0.173 | Tasa éxito:  18.0% | p_attack media:  0.805 | dist media:  0.999
# [AttackLogger] Episodios:   2700 | Reward medio:  0.115 | Tasa éxito:  12.0% | p_attack media:  0.844 | dist media:  1.000
# [AttackLogger] Episodios:   2800 | Reward medio:  0.174 | Tasa éxito:  18.0% | p_attack media:  0.822 | dist media:  1.000
# [AttackLogger] Episodios:   2900 | Reward medio:  0.073 | Tasa éxito:   8.0% | p_attack media:  0.872 | dist media:  1.000
# [AttackLogger] Episodios:   3000 | Reward medio:  0.175 | Tasa éxito:  18.0% | p_attack media:  0.824 | dist media:  1.000
# [AttackLogger] Episodios:   3100 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:   3200 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.861 | dist media:  1.000
# [AttackLogger] Episodios:   3300 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.849 | dist media:  1.000
# [AttackLogger] Episodios:   3400 | Reward medio:  0.065 | Tasa éxito:   7.0% | p_attack media:  0.895 | dist media:  1.000
# [AttackLogger] Episodios:   3500 | Reward medio:  0.134 | Tasa éxito:  14.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:   3600 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:   3700 | Reward medio:  0.114 | Tasa éxito:  12.0% | p_attack media:  0.844 | dist media:  1.000
# [AttackLogger] Episodios:   3800 | Reward medio:  0.136 | Tasa éxito:  14.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:   3900 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:   4000 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.856 | dist media:  1.000
# [AttackLogger] Episodios:   4100 | Reward medio:  0.145 | Tasa éxito:  15.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:   4200 | Reward medio:  0.062 | Tasa éxito:   7.0% | p_attack media:  0.886 | dist media:  1.000
# [AttackLogger] Episodios:   4300 | Reward medio:  0.173 | Tasa éxito:  18.0% | p_attack media:  0.803 | dist media:  1.000
# [AttackLogger] Episodios:   4400 | Reward medio:  0.154 | Tasa éxito:  16.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:   4500 | Reward medio:  0.095 | Tasa éxito:  10.0% | p_attack media:  0.881 | dist media:  1.000
# [AttackLogger] Episodios:   4600 | Reward medio:  0.165 | Tasa éxito:  17.0% | p_attack media:  0.822 | dist media:  1.000
# [AttackLogger] Episodios:   4700 | Reward medio:  0.134 | Tasa éxito:  14.0% | p_attack media:  0.853 | dist media:  1.000
# [AttackLogger] Episodios:   4800 | Reward medio:  0.055 | Tasa éxito:   6.0% | p_attack media:  0.878 | dist media:  1.000
# [AttackLogger] Episodios:   4900 | Reward medio:  0.193 | Tasa éxito:  20.0% | p_attack media:  0.811 | dist media:  1.000
# [AttackLogger] Episodios:   5000 | Reward medio:  0.095 | Tasa éxito:  10.0% | p_attack media:  0.866 | dist media:  1.000
# [AttackLogger] Episodios:   5100 | Reward medio:  0.132 | Tasa éxito:  14.0% | p_attack media:  0.852 | dist media:  1.000
# [AttackLogger] Episodios:   5200 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.810 | dist media:  1.000
# [AttackLogger] Episodios:   5300 | Reward medio:  0.092 | Tasa éxito:  10.0% | p_attack media:  0.860 | dist media:  1.000
# [AttackLogger] Episodios:   5400 | Reward medio:  0.102 | Tasa éxito:  11.0% | p_attack media:  0.856 | dist media:  1.000
# [AttackLogger] Episodios:   5500 | Reward medio:  0.104 | Tasa éxito:  11.0% | p_attack media:  0.874 | dist media:  1.000
# [AttackLogger] Episodios:   5600 | Reward medio:  0.153 | Tasa éxito:  16.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:   5700 | Reward medio:  0.173 | Tasa éxito:  18.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:   5800 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.841 | dist media:  1.000
# [AttackLogger] Episodios:   5900 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.849 | dist media:  1.000
# [AttackLogger] Episodios:   6000 | Reward medio:  0.173 | Tasa éxito:  18.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:   6100 | Reward medio:  0.112 | Tasa éxito:  12.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:   6200 | Reward medio:  0.156 | Tasa éxito:  16.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:   6300 | Reward medio:  0.104 | Tasa éxito:  11.0% | p_attack media:  0.880 | dist media:  1.000
# [AttackLogger] Episodios:   6400 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.855 | dist media:  1.000
# [AttackLogger] Episodios:   6500 | Reward medio:  0.136 | Tasa éxito:  14.0% | p_attack media:  0.842 | dist media:  1.000
# [AttackLogger] Episodios:   6600 | Reward medio:  0.184 | Tasa éxito:  19.0% | p_attack media:  0.812 | dist media:  1.000
# [AttackLogger] Episodios:   6700 | Reward medio:  0.122 | Tasa éxito:  13.0% | p_attack media:  0.849 | dist media:  1.000
# [AttackLogger] Episodios:   6800 | Reward medio:  0.133 | Tasa éxito:  14.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:   6900 | Reward medio:  0.115 | Tasa éxito:  12.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:   7000 | Reward medio:  0.135 | Tasa éxito:  14.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:   7100 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:   7200 | Reward medio:  0.133 | Tasa éxito:  14.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:   7300 | Reward medio:  0.115 | Tasa éxito:  12.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:   7400 | Reward medio:  0.044 | Tasa éxito:   5.0% | p_attack media:  0.895 | dist media:  1.000
# [AttackLogger] Episodios:   7500 | Reward medio:  0.124 | Tasa éxito:  13.0% | p_attack media:  0.857 | dist media:  1.000
# [AttackLogger] Episodios:   7600 | Reward medio:  0.134 | Tasa éxito:  14.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:   7700 | Reward medio:  0.084 | Tasa éxito:   9.0% | p_attack media:  0.853 | dist media:  0.999
# [AttackLogger] Episodios:   7800 | Reward medio:  0.093 | Tasa éxito:  10.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:   7900 | Reward medio:  0.116 | Tasa éxito:  12.0% | p_attack media:  0.853 | dist media:  1.000
# [AttackLogger] Episodios:   8000 | Reward medio:  0.074 | Tasa éxito:   8.0% | p_attack media:  0.869 | dist media:  1.000
# [AttackLogger] Episodios:   8100 | Reward medio:  0.125 | Tasa éxito:  13.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:   8200 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.835 | dist media:  1.000
# [AttackLogger] Episodios:   8300 | Reward medio:  0.055 | Tasa éxito:   6.0% | p_attack media:  0.903 | dist media:  1.000
# [AttackLogger] Episodios:   8400 | Reward medio:  0.074 | Tasa éxito:   8.0% | p_attack media:  0.877 | dist media:  1.000
# [AttackLogger] Episodios:   8500 | Reward medio:  0.163 | Tasa éxito:  17.0% | p_attack media:  0.815 | dist media:  1.000
# [AttackLogger] Episodios:   8600 | Reward medio:  0.174 | Tasa éxito:  18.0% | p_attack media:  0.805 | dist media:  1.000
# [AttackLogger] Episodios:   8700 | Reward medio:  0.146 | Tasa éxito:  15.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:   8800 | Reward medio:  0.133 | Tasa éxito:  14.0% | p_attack media:  0.855 | dist media:  1.000
# [AttackLogger] Episodios:   8900 | Reward medio:  0.163 | Tasa éxito:  17.0% | p_attack media:  0.805 | dist media:  1.000
# [AttackLogger] Episodios:   9000 | Reward medio:  0.174 | Tasa éxito:  18.0% | p_attack media:  0.813 | dist media:  1.000
# [AttackLogger] Episodios:   9100 | Reward medio:  0.145 | Tasa éxito:  15.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:   9200 | Reward medio:  0.073 | Tasa éxito:   8.0% | p_attack media:  0.864 | dist media:  1.000
# [AttackLogger] Episodios:   9300 | Reward medio:  0.103 | Tasa éxito:  11.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:   9400 | Reward medio:  0.138 | Tasa éxito:  14.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:   9500 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:   9600 | Reward medio:  0.142 | Tasa éxito:  15.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:   9700 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.842 | dist media:  0.997
# [AttackLogger] Episodios:   9800 | Reward medio:  0.105 | Tasa éxito:  11.0% | p_attack media:  0.867 | dist media:  1.000
# [AttackLogger] Episodios:   9900 | Reward medio:  0.094 | Tasa éxito:  10.0% | p_attack media:  0.863 | dist media:  1.000
# [AttackLogger] Episodios:  10000 | Reward medio:  0.134 | Tasa éxito:  14.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  10100 | Reward medio:  0.133 | Tasa éxito:  14.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  10200 | Reward medio:  0.095 | Tasa éxito:  10.0% | p_attack media:  0.851 | dist media:  1.000
# [AttackLogger] Episodios:  10300 | Reward medio:  0.082 | Tasa éxito:   9.0% | p_attack media:  0.864 | dist media:  1.000
# [AttackLogger] Episodios:  10400 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.868 | dist media:  1.000
# [AttackLogger] Episodios:  10500 | Reward medio:  0.155 | Tasa éxito:  16.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  10600 | Reward medio:  0.214 | Tasa éxito:  22.0% | p_attack media:  0.776 | dist media:  1.000
# [AttackLogger] Episodios:  10700 | Reward medio:  0.162 | Tasa éxito:  17.0% | p_attack media:  0.814 | dist media:  1.000
# [AttackLogger] Episodios:  10800 | Reward medio:  0.103 | Tasa éxito:  11.0% | p_attack media:  0.867 | dist media:  1.000
# [AttackLogger] Episodios:  10900 | Reward medio:  0.155 | Tasa éxito:  16.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:  11000 | Reward medio:  0.076 | Tasa éxito:   8.0% | p_attack media:  0.856 | dist media:  1.000
# [AttackLogger] Episodios:  11100 | Reward medio:  0.183 | Tasa éxito:  19.0% | p_attack media:  0.803 | dist media:  1.000
# [AttackLogger] Episodios:  11200 | Reward medio:  0.183 | Tasa éxito:  19.0% | p_attack media:  0.795 | dist media:  1.000
# [AttackLogger] Episodios:  11300 | Reward medio:  0.125 | Tasa éxito:  13.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  11400 | Reward medio:  0.242 | Tasa éxito:  25.0% | p_attack media:  0.767 | dist media:  0.999
# [AttackLogger] Episodios:  11500 | Reward medio:  0.132 | Tasa éxito:  14.0% | p_attack media:  0.856 | dist media:  1.000
# [AttackLogger] Episodios:  11600 | Reward medio:  0.040 | Tasa éxito:   5.0% | p_attack media:  0.909 | dist media:  1.000
# [AttackLogger] Episodios:  11700 | Reward medio:  0.124 | Tasa éxito:  13.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  11800 | Reward medio:  0.094 | Tasa éxito:  10.0% | p_attack media:  0.893 | dist media:  1.000
# [AttackLogger] Episodios:  11900 | Reward medio:  0.153 | Tasa éxito:  16.0% | p_attack media:  0.819 | dist media:  0.999
# [AttackLogger] Episodios:  12000 | Reward medio:  0.135 | Tasa éxito:  14.0% | p_attack media:  0.839 | dist media:  0.999
# [AttackLogger] Episodios:  12100 | Reward medio:  0.164 | Tasa éxito:  17.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:  12200 | Reward medio:  0.103 | Tasa éxito:  11.0% | p_attack media:  0.869 | dist media:  1.000
# [AttackLogger] Episodios:  12300 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  12400 | Reward medio:  0.085 | Tasa éxito:   9.0% | p_attack media:  0.877 | dist media:  1.000
# [AttackLogger] Episodios:  12500 | Reward medio:  0.115 | Tasa éxito:  12.0% | p_attack media:  0.847 | dist media:  0.999
# [AttackLogger] Episodios:  12600 | Reward medio:  0.124 | Tasa éxito:  13.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  12700 | Reward medio:  0.155 | Tasa éxito:  16.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  12800 | Reward medio:  0.174 | Tasa éxito:  18.0% | p_attack media:  0.826 | dist media:  1.000
# [AttackLogger] Episodios:  12900 | Reward medio:  0.167 | Tasa éxito:  17.0% | p_attack media:  0.808 | dist media:  1.000
# [AttackLogger] Episodios:  13000 | Reward medio:  0.104 | Tasa éxito:  11.0% | p_attack media:  0.872 | dist media:  0.995
# [AttackLogger] Episodios:  13100 | Reward medio:  0.196 | Tasa éxito:  20.0% | p_attack media:  0.792 | dist media:  1.000
# [AttackLogger] Episodios:  13200 | Reward medio:  0.146 | Tasa éxito:  15.0% | p_attack media:  0.824 | dist media:  1.000
# [AttackLogger] Episodios:  13300 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:  13400 | Reward medio:  0.126 | Tasa éxito:  13.0% | p_attack media:  0.852 | dist media:  0.999
# [AttackLogger] Episodios:  13500 | Reward medio:  0.074 | Tasa éxito:   8.0% | p_attack media:  0.879 | dist media:  1.000
# [AttackLogger] Episodios:  13600 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.833 | dist media:  0.997
# [AttackLogger] Episodios:  13700 | Reward medio:  0.146 | Tasa éxito:  15.0% | p_attack media:  0.838 | dist media:  1.000
# [AttackLogger] Episodios:  13800 | Reward medio:  0.046 | Tasa éxito:   5.0% | p_attack media:  0.894 | dist media:  1.000
# [AttackLogger] Episodios:  13900 | Reward medio:  0.154 | Tasa éxito:  16.0% | p_attack media:  0.842 | dist media:  1.000
# [AttackLogger] Episodios:  14000 | Reward medio:  0.103 | Tasa éxito:  11.0% | p_attack media:  0.855 | dist media:  1.000
# [AttackLogger] Episodios:  14100 | Reward medio:  0.094 | Tasa éxito:  10.0% | p_attack media:  0.861 | dist media:  1.000
# [AttackLogger] Episodios:  14200 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.861 | dist media:  1.000
# [AttackLogger] Episodios:  14300 | Reward medio:  0.166 | Tasa éxito:  17.0% | p_attack media:  0.848 | dist media:  1.000
# [AttackLogger] Episodios:  14400 | Reward medio:  0.186 | Tasa éxito:  19.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:  14500 | Reward medio:  0.094 | Tasa éxito:  10.0% | p_attack media:  0.879 | dist media:  1.000
# [AttackLogger] Episodios:  14600 | Reward medio:  0.115 | Tasa éxito:  12.0% | p_attack media:  0.856 | dist media:  1.000
# [AttackLogger] Episodios:  14700 | Reward medio:  0.084 | Tasa éxito:   9.0% | p_attack media:  0.863 | dist media:  0.996
# [AttackLogger] Episodios:  14800 | Reward medio:  0.125 | Tasa éxito:  13.0% | p_attack media:  0.844 | dist media:  1.000
# [AttackLogger] Episodios:  14900 | Reward medio:  0.112 | Tasa éxito:  12.0% | p_attack media:  0.841 | dist media:  1.000
# [AttackLogger] Episodios:  15000 | Reward medio:  0.115 | Tasa éxito:  12.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  15100 | Reward medio:  0.103 | Tasa éxito:  11.0% | p_attack media:  0.858 | dist media:  1.000
# [AttackLogger] Episodios:  15200 | Reward medio:  0.152 | Tasa éxito:  16.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  15300 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:  15400 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:  15500 | Reward medio:  0.044 | Tasa éxito:   5.0% | p_attack media:  0.918 | dist media:  1.000
# [AttackLogger] Episodios:  15600 | Reward medio:  0.135 | Tasa éxito:  14.0% | p_attack media:  0.822 | dist media:  1.000
# [AttackLogger] Episodios:  15700 | Reward medio:  0.082 | Tasa éxito:   9.0% | p_attack media:  0.869 | dist media:  0.999
# [AttackLogger] Episodios:  15800 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.867 | dist media:  1.000
# [AttackLogger] Episodios:  15900 | Reward medio:  0.103 | Tasa éxito:  11.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:  16000 | Reward medio:  0.134 | Tasa éxito:  14.0% | p_attack media:  0.834 | dist media:  1.000
# [AttackLogger] Episodios:  16100 | Reward medio:  0.117 | Tasa éxito:  12.0% | p_attack media:  0.848 | dist media:  0.996
# [AttackLogger] Episodios:  16200 | Reward medio:  0.074 | Tasa éxito:   8.0% | p_attack media:  0.887 | dist media:  1.000
# [AttackLogger] Episodios:  16300 | Reward medio:  0.145 | Tasa éxito:  15.0% | p_attack media:  0.841 | dist media:  1.000
# [AttackLogger] Episodios:  16400 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.851 | dist media:  0.999
# [AttackLogger] Episodios:  16500 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.856 | dist media:  1.000
# [AttackLogger] Episodios:  16600 | Reward medio:  0.044 | Tasa éxito:   5.0% | p_attack media:  0.894 | dist media:  1.000
# [AttackLogger] Episodios:  16700 | Reward medio:  0.073 | Tasa éxito:   8.0% | p_attack media:  0.885 | dist media:  1.000
# [AttackLogger] Episodios:  16800 | Reward medio:  0.076 | Tasa éxito:   8.0% | p_attack media:  0.883 | dist media:  0.999
# [AttackLogger] Episodios:  16900 | Reward medio:  0.127 | Tasa éxito:  13.0% | p_attack media:  0.841 | dist media:  0.999
# [AttackLogger] Episodios:  17000 | Reward medio:  0.186 | Tasa éxito:  19.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:  17100 | Reward medio:  0.084 | Tasa éxito:   9.0% | p_attack media:  0.882 | dist media:  0.998
# [AttackLogger] Episodios:  17200 | Reward medio:  0.144 | Tasa éxito:  15.0% | p_attack media:  0.813 | dist media:  1.000
# [AttackLogger] Episodios:  17300 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  17400 | Reward medio:  0.086 | Tasa éxito:   9.0% | p_attack media:  0.872 | dist media:  1.000
# [AttackLogger] Episodios:  17500 | Reward medio:  0.058 | Tasa éxito:   6.0% | p_attack media:  0.892 | dist media:  1.000
# [AttackLogger] Episodios:  17600 | Reward medio:  0.093 | Tasa éxito:  10.0% | p_attack media:  0.882 | dist media:  1.000
# [AttackLogger] Episodios:  17700 | Reward medio:  0.181 | Tasa éxito:  19.0% | p_attack media:  0.816 | dist media:  0.999
# [AttackLogger] Episodios:  17800 | Reward medio:  0.072 | Tasa éxito:   8.0% | p_attack media:  0.873 | dist media:  1.000
# [AttackLogger] Episodios:  17900 | Reward medio:  0.165 | Tasa éxito:  17.0% | p_attack media:  0.804 | dist media:  1.000
# [AttackLogger] Episodios:  18000 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:  18100 | Reward medio:  0.086 | Tasa éxito:   9.0% | p_attack media:  0.887 | dist media:  1.000
# [AttackLogger] Episodios:  18200 | Reward medio:  0.093 | Tasa éxito:  10.0% | p_attack media:  0.859 | dist media:  1.000
# [AttackLogger] Episodios:  18300 | Reward medio:  0.122 | Tasa éxito:  13.0% | p_attack media:  0.844 | dist media:  0.997
# [AttackLogger] Episodios:  18400 | Reward medio:  0.164 | Tasa éxito:  17.0% | p_attack media:  0.804 | dist media:  1.000
# [AttackLogger] Episodios:  18500 | Reward medio:  0.152 | Tasa éxito:  16.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:  18600 | Reward medio:  0.075 | Tasa éxito:   8.0% | p_attack media:  0.867 | dist media:  1.000
# [AttackLogger] Episodios:  18700 | Reward medio:  0.173 | Tasa éxito:  18.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:  18800 | Reward medio:  0.106 | Tasa éxito:  11.0% | p_attack media:  0.865 | dist media:  0.996
# [AttackLogger] Episodios:  18900 | Reward medio:  0.136 | Tasa éxito:  14.0% | p_attack media:  0.842 | dist media:  1.000
# [AttackLogger] Episodios:  19000 | Reward medio:  0.124 | Tasa éxito:  13.0% | p_attack media:  0.844 | dist media:  1.000
# [AttackLogger] Episodios:  19100 | Reward medio:  0.125 | Tasa éxito:  13.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  19200 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  19300 | Reward medio:  0.060 | Tasa éxito:   7.0% | p_attack media:  0.878 | dist media:  1.000
# [AttackLogger] Episodios:  19400 | Reward medio:  0.136 | Tasa éxito:  14.0% | p_attack media:  0.850 | dist media:  1.000
# [AttackLogger] Episodios:  19500 | Reward medio:  0.113 | Tasa éxito:  12.0% | p_attack media:  0.852 | dist media:  1.000
# [AttackLogger] Episodios:  19600 | Reward medio:  0.126 | Tasa éxito:  13.0% | p_attack media:  0.825 | dist media:  1.000
# [AttackLogger] Episodios:  19700 | Reward medio:  0.133 | Tasa éxito:  14.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:  19800 | Reward medio:  0.114 | Tasa éxito:  12.0% | p_attack media:  0.866 | dist media:  1.000
# [AttackLogger] Episodios:  19900 | Reward medio:  0.184 | Tasa éxito:  19.0% | p_attack media:  0.819 | dist media:  1.000
# [AttackLogger] Episodios:  20000 | Reward medio:  0.106 | Tasa éxito:  11.0% | p_attack media:  0.876 | dist media:  1.000

# %% [markdown]
# Gráficas de SAC

# %%
# Configuración de gráficos para visualizar los resultados
plt.style.use("seaborn-v0_8-whitegrid")

# Datos para graficar
episodes = np.array(callback.history_episodes)
success_rate = np.array(callback.history_success_rate) * 100
mean_reward = np.array(callback.history_mean_reward)
mean_p_attack = np.array(callback.history_mean_p_attack)

# %%
# Gáfico de Tasa de éxito
success_rate = np.array(callback.history_success_rate) * 100

# Suavizado
window = 5
smooth_success = uniform_filter1d(success_rate, size=window)
mean = smooth_success
std = uniform_filter1d(np.abs(success_rate - mean), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Grafico de Tasa de éxito
plt.plot(episodes, mean, linewidth=2.2, color="#007acc")
plt.fill_between(
    episodes,
    mean - std,
    mean + std,
    color="#007acc",
    alpha=0.15
)
plt.title("Tasa de éxito del atacante", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Éxito (%)", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Reward medio
mean_reward = np.array(callback.history_mean_reward)

# Suavizado
window = 5
smooth_reward = uniform_filter1d(mean_reward, size=window)

# Desviación estándar local
std_reward = uniform_filter1d(np.abs(mean_reward - smooth_reward), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_reward, linewidth=2.2, color="#d35400")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_reward - std_reward,
    smooth_reward + std_reward,
    color="#d35400",
    alpha=0.15
)
plt.title("Reward medio por ventana (100 episodios)", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Reward", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# TODO

# %%
# Probabilidad media de ataque
mean_p_attack = np.array(callback.history_mean_p_attack)

# Suavizado
window = 5
smooth_p_attack = uniform_filter1d(mean_p_attack, size=window)

# Desviación estándar local
std_p_attack = uniform_filter1d(np.abs(mean_p_attack - smooth_p_attack), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_p_attack, linewidth=2.2, color="#8e44ad")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_p_attack - std_p_attack,
    smooth_p_attack + std_p_attack,
    color="#8e44ad",
    alpha=0.15
)
plt.title("Probabilidad media final de ataque", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("p_attack", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de SAC

# %%
# Creamos un entorno vectorizado para evaluación
eval_env = DummyVecEnv([make_env])

# Cargamos la normalización del entorno usado en entrenamiento
eval_env = VecNormalize.load("../../agents/v1/sac_attacker_limited_multistep_vecnorm.pkl", eval_env)

# Desactivamos el entrenamiento, de manera que las estadísticas de normalización no se actualicen durante la evaluación 
eval_env.training = False

# Desactivamos la normalización de recompensas para la evaluación (cuando evaluamos queremos las recompensas reales)
eval_env.norm_reward = False

# Cargamos el modelo entrenado
model = SAC.load("../../agents/v1/sac_attacker_limited_multistep")

# Evaluamos el agente SAC atacante con 300 episodios
success_rate, mean_final_p, mean_final_dist = evaluate_sac_attacker(model, eval_env, n_episodes=300)

# Mostramos los resultados finales de la evaluación
print(f"Tasa de evasión (episodio completo): {success_rate*100:.3f}%")
print(f"Probabilidad media final de ataque: {mean_final_p*100:.3f}%") # La probabilidad media de que el estado modificado por el agente sea catalogado como ataque
print(f"Distancia media final de la perturbación: {mean_final_dist:.3f}") # La distancia media entre x_adv y x_orig (tamaño medio de la perturbación)
# Out:
# Tasa de evasión (episodio completo): 11.333%
# Probabilidad media final de ataque: 86.481%
# Distancia media final de la perturbación: 1.000

# %% [markdown]
# Conclusiones de SAC

# %%
# Muestreamos 300 ataques adversariales generados por el agente SAC multi-step
xs_orig, xs_adv, successes, mean_final_dist = sample_adversarials_multistep(model, eval_env, n_episodes=300)

# Configuración de gráficos
plt.figure(figsize=(6, 6))

# Pintamos los ataques originales de color azul claro
plt.scatter(xs_orig[:, 0], xs_orig[:, 1], alpha=0.3, label="Original (ataque)")

# Pintamos los ataques adversariales que lograron evadir el detector de color naranja
mask_ok = successes == 1
plt.scatter(xs_adv[mask_ok, 0], xs_adv[mask_ok, 1], alpha=0.7, label="Adversarial (evade)")
plt.legend()
plt.grid(True)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Ataques adversariales aprendidos por el agente (multi-step SAC)")
plt.show()

# %% [markdown]
# Entrenamiento del agente PPO

# %%
# Arquitectura de la red neuronal del actor y crítico (PPO también usa MLP para policy y value)
policy_kwargs = dict(net_arch=[256, 256])

# Modelo PPO
model = PPO(
    "MlpPolicy",
    venv,  # Entorno vectorizado y normalizado
    verbose=0,  # No muestra info en consola (pon 1 si quieres ver logs)
    policy_kwargs=policy_kwargs,  # Arquitectura de la red
    learning_rate=3e-4,   # Tasa de aprendizaje
    n_steps=128,          # Pasos por actualización (pequeño porque tus episodios son muy cortos)
    batch_size=64,        # Tamaño de batch para actualizar
    gamma=0.99,           # Factor de descuento
    clip_range=0.2,       # Clip de PPO
    ent_coef=0.0,         # Coeficiente de entropía (0 si no quieres forzar exploración extra)
)

# Callback de logging (el mismo que ya tienes)
callback_PPO = AttackLoggerCallback(log_freq=100)

# Entrenamiento del agente PPO
model.learn(total_timesteps=200_000, callback=callback_PPO)

# Guardamos el modelo entrenado y el entorno normalizado
model.save("../../agents/v1/ppo_attacker_limited_multistep")
venv.save("../../agents/v1/ppo_attacker_limited_multistep_vecnorm.pkl")
# Out:
# [AttackLogger] Episodios:    100 | Reward medio:  0.007 | Tasa éxito:   2.0% | p_attack media:  0.957 | dist media:  0.787
# [AttackLogger] Episodios:    200 | Reward medio:  0.050 | Tasa éxito:   5.0% | p_attack media:  0.932 | dist media:  0.878
# [AttackLogger] Episodios:    300 | Reward medio:  0.022 | Tasa éxito:   4.0% | p_attack media:  0.938 | dist media:  0.955
# [AttackLogger] Episodios:    400 | Reward medio:  0.126 | Tasa éxito:  12.0% | p_attack media:  0.862 | dist media:  0.936
# [AttackLogger] Episodios:    500 | Reward medio:  0.073 | Tasa éxito:   8.0% | p_attack media:  0.885 | dist media:  0.982
# [AttackLogger] Episodios:    600 | Reward medio:  0.145 | Tasa éxito:  15.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:    700 | Reward medio:  0.092 | Tasa éxito:  10.0% | p_attack media:  0.871 | dist media:  0.994
# [AttackLogger] Episodios:    800 | Reward medio:  0.114 | Tasa éxito:  12.0% | p_attack media:  0.833 | dist media:  0.995
# [AttackLogger] Episodios:    900 | Reward medio:  0.082 | Tasa éxito:   9.0% | p_attack media:  0.876 | dist media:  0.997
# [AttackLogger] Episodios:   1000 | Reward medio:  0.144 | Tasa éxito:  15.0% | p_attack media:  0.844 | dist media:  0.992
# [AttackLogger] Episodios:   1100 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.842 | dist media:  0.992
# [AttackLogger] Episodios:   1200 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:   1300 | Reward medio:  0.108 | Tasa éxito:  12.0% | p_attack media:  0.859 | dist media:  0.991
# [AttackLogger] Episodios:   1400 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.817 | dist media:  1.000
# [AttackLogger] Episodios:   1500 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.800 | dist media:  1.000
# [AttackLogger] Episodios:   1600 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.804 | dist media:  0.995
# [AttackLogger] Episodios:   1700 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.841 | dist media:  1.000
# [AttackLogger] Episodios:   1800 | Reward medio:  0.171 | Tasa éxito:  18.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:   1900 | Reward medio:  0.069 | Tasa éxito:   8.0% | p_attack media:  0.880 | dist media:  1.000
# [AttackLogger] Episodios:   2000 | Reward medio:  0.132 | Tasa éxito:  14.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:   2100 | Reward medio:  0.072 | Tasa éxito:   8.0% | p_attack media:  0.868 | dist media:  0.996
# [AttackLogger] Episodios:   2200 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.835 | dist media:  0.997
# [AttackLogger] Episodios:   2300 | Reward medio:  0.104 | Tasa éxito:  11.0% | p_attack media:  0.844 | dist media:  1.000
# [AttackLogger] Episodios:   2400 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.826 | dist media:  1.000
# [AttackLogger] Episodios:   2500 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.871 | dist media:  1.000
# [AttackLogger] Episodios:   2600 | Reward medio:  0.154 | Tasa éxito:  16.0% | p_attack media:  0.813 | dist media:  1.000
# [AttackLogger] Episodios:   2700 | Reward medio:  0.159 | Tasa éxito:  17.0% | p_attack media:  0.817 | dist media:  1.000
# [AttackLogger] Episodios:   2800 | Reward medio:  0.089 | Tasa éxito:  10.0% | p_attack media:  0.866 | dist media:  1.000
# [AttackLogger] Episodios:   2900 | Reward medio:  0.080 | Tasa éxito:   9.0% | p_attack media:  0.870 | dist media:  1.000
# [AttackLogger] Episodios:   3000 | Reward medio:  0.093 | Tasa éxito:  10.0% | p_attack media:  0.859 | dist media:  1.000
# [AttackLogger] Episodios:   3100 | Reward medio:  0.118 | Tasa éxito:  13.0% | p_attack media:  0.852 | dist media:  1.000
# [AttackLogger] Episodios:   3200 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.852 | dist media:  1.000
# [AttackLogger] Episodios:   3300 | Reward medio:  0.158 | Tasa éxito:  17.0% | p_attack media:  0.808 | dist media:  0.990
# [AttackLogger] Episodios:   3400 | Reward medio:  0.102 | Tasa éxito:  11.0% | p_attack media:  0.861 | dist media:  0.999
# [AttackLogger] Episodios:   3500 | Reward medio:  0.175 | Tasa éxito:  18.0% | p_attack media:  0.795 | dist media:  1.000
# [AttackLogger] Episodios:   3600 | Reward medio:  0.138 | Tasa éxito:  15.0% | p_attack media:  0.825 | dist media:  1.000
# [AttackLogger] Episodios:   3700 | Reward medio:  0.095 | Tasa éxito:  10.0% | p_attack media:  0.834 | dist media:  1.000
# [AttackLogger] Episodios:   3800 | Reward medio:  0.124 | Tasa éxito:  13.0% | p_attack media:  0.859 | dist media:  1.000
# [AttackLogger] Episodios:   3900 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.825 | dist media:  1.000
# [AttackLogger] Episodios:   4000 | Reward medio:  0.160 | Tasa éxito:  18.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:   4100 | Reward medio:  0.186 | Tasa éxito:  19.0% | p_attack media:  0.791 | dist media:  1.000
# [AttackLogger] Episodios:   4200 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:   4300 | Reward medio:  0.093 | Tasa éxito:  10.0% | p_attack media:  0.866 | dist media:  1.000
# [AttackLogger] Episodios:   4400 | Reward medio:  0.171 | Tasa éxito:  18.0% | p_attack media:  0.788 | dist media:  1.000
# [AttackLogger] Episodios:   4500 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.849 | dist media:  1.000
# [AttackLogger] Episodios:   4600 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.803 | dist media:  1.000
# [AttackLogger] Episodios:   4700 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:   4800 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.832 | dist media:  0.998
# [AttackLogger] Episodios:   4900 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.800 | dist media:  1.000
# [AttackLogger] Episodios:   5000 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.857 | dist media:  0.998
# [AttackLogger] Episodios:   5100 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:   5200 | Reward medio:  0.102 | Tasa éxito:  11.0% | p_attack media:  0.862 | dist media:  1.000
# [AttackLogger] Episodios:   5300 | Reward medio:  0.091 | Tasa éxito:  10.0% | p_attack media:  0.859 | dist media:  1.000
# [AttackLogger] Episodios:   5400 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.810 | dist media:  1.000
# [AttackLogger] Episodios:   5500 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.841 | dist media:  0.996
# [AttackLogger] Episodios:   5600 | Reward medio:  0.181 | Tasa éxito:  19.0% | p_attack media:  0.789 | dist media:  1.000
# [AttackLogger] Episodios:   5700 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.834 | dist media:  0.999
# [AttackLogger] Episodios:   5800 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:   5900 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:   6000 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.794 | dist media:  1.000
# [AttackLogger] Episodios:   6100 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:   6200 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.795 | dist media:  1.000
# [AttackLogger] Episodios:   6300 | Reward medio:  0.132 | Tasa éxito:  14.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:   6400 | Reward medio:  0.071 | Tasa éxito:   8.0% | p_attack media:  0.862 | dist media:  1.000
# [AttackLogger] Episodios:   6500 | Reward medio:  0.171 | Tasa éxito:  18.0% | p_attack media:  0.797 | dist media:  1.000
# [AttackLogger] Episodios:   6600 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.808 | dist media:  1.000
# [AttackLogger] Episodios:   6700 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:   6800 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:   6900 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:   7000 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:   7100 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:   7200 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.796 | dist media:  1.000
# [AttackLogger] Episodios:   7300 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:   7400 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:   7500 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.812 | dist media:  1.000
# [AttackLogger] Episodios:   7600 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:   7700 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.826 | dist media:  1.000
# [AttackLogger] Episodios:   7800 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:   7900 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.819 | dist media:  1.000
# [AttackLogger] Episodios:   8000 | Reward medio:  0.102 | Tasa éxito:  11.0% | p_attack media:  0.866 | dist media:  1.000
# [AttackLogger] Episodios:   8100 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:   8200 | Reward medio:  0.118 | Tasa éxito:  13.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:   8300 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:   8400 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.851 | dist media:  1.000
# [AttackLogger] Episodios:   8500 | Reward medio:  0.201 | Tasa éxito:  21.0% | p_attack media:  0.756 | dist media:  1.000
# [AttackLogger] Episodios:   8600 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:   8700 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:   8800 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:   8900 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.844 | dist media:  1.000
# [AttackLogger] Episodios:   9000 | Reward medio:  0.152 | Tasa éxito:  16.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:   9100 | Reward medio:  0.181 | Tasa éxito:  19.0% | p_attack media:  0.784 | dist media:  1.000
# [AttackLogger] Episodios:   9200 | Reward medio:  0.071 | Tasa éxito:   8.0% | p_attack media:  0.870 | dist media:  1.000
# [AttackLogger] Episodios:   9300 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:   9400 | Reward medio:  0.158 | Tasa éxito:  17.0% | p_attack media:  0.815 | dist media:  0.998
# [AttackLogger] Episodios:   9500 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.815 | dist media:  1.000
# [AttackLogger] Episodios:   9600 | Reward medio:  0.082 | Tasa éxito:   9.0% | p_attack media:  0.864 | dist media:  1.000
# [AttackLogger] Episodios:   9700 | Reward medio:  0.119 | Tasa éxito:  13.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:   9800 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.822 | dist media:  1.000
# [AttackLogger] Episodios:   9900 | Reward medio:  0.191 | Tasa éxito:  20.0% | p_attack media:  0.804 | dist media:  1.000
# [AttackLogger] Episodios:  10000 | Reward medio:  0.071 | Tasa éxito:   8.0% | p_attack media:  0.875 | dist media:  1.000
# [AttackLogger] Episodios:  10100 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  10200 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.834 | dist media:  1.000
# [AttackLogger] Episodios:  10300 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:  10400 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:  10500 | Reward medio:  0.091 | Tasa éxito:  10.0% | p_attack media:  0.871 | dist media:  1.000
# [AttackLogger] Episodios:  10600 | Reward medio:  0.060 | Tasa éxito:   7.0% | p_attack media:  0.882 | dist media:  1.000
# [AttackLogger] Episodios:  10700 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.841 | dist media:  1.000
# [AttackLogger] Episodios:  10800 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.829 | dist media:  0.998
# [AttackLogger] Episodios:  10900 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.848 | dist media:  1.000
# [AttackLogger] Episodios:  11000 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.809 | dist media:  1.000
# [AttackLogger] Episodios:  11100 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.822 | dist media:  1.000
# [AttackLogger] Episodios:  11200 | Reward medio:  0.091 | Tasa éxito:  10.0% | p_attack media:  0.860 | dist media:  1.000
# [AttackLogger] Episodios:  11300 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  11400 | Reward medio:  0.190 | Tasa éxito:  20.0% | p_attack media:  0.800 | dist media:  1.000
# [AttackLogger] Episodios:  11500 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  11600 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:  11700 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:  11800 | Reward medio:  0.168 | Tasa éxito:  18.0% | p_attack media:  0.803 | dist media:  1.000
# [AttackLogger] Episodios:  11900 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:  12000 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.818 | dist media:  1.000
# [AttackLogger] Episodios:  12100 | Reward medio:  0.049 | Tasa éxito:   6.0% | p_attack media:  0.914 | dist media:  1.000
# [AttackLogger] Episodios:  12200 | Reward medio:  0.122 | Tasa éxito:  13.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  12300 | Reward medio:  0.139 | Tasa éxito:  15.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:  12400 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:  12500 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  12600 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:  12700 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.804 | dist media:  1.000
# [AttackLogger] Episodios:  12800 | Reward medio:  0.177 | Tasa éxito:  19.0% | p_attack media:  0.797 | dist media:  1.000
# [AttackLogger] Episodios:  12900 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  13000 | Reward medio:  0.137 | Tasa éxito:  15.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  13100 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.848 | dist media:  1.000
# [AttackLogger] Episodios:  13200 | Reward medio:  0.106 | Tasa éxito:  12.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:  13300 | Reward medio:  0.129 | Tasa éxito:  14.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:  13400 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.863 | dist media:  1.000
# [AttackLogger] Episodios:  13500 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.804 | dist media:  1.000
# [AttackLogger] Episodios:  13600 | Reward medio:  0.164 | Tasa éxito:  17.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:  13700 | Reward medio:  0.122 | Tasa éxito:  13.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  13800 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.810 | dist media:  1.000
# [AttackLogger] Episodios:  13900 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:  14000 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.872 | dist media:  1.000
# [AttackLogger] Episodios:  14100 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.789 | dist media:  1.000
# [AttackLogger] Episodios:  14200 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.809 | dist media:  1.000
# [AttackLogger] Episodios:  14300 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:  14400 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  14500 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  14600 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:  14700 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:  14800 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:  14900 | Reward medio:  0.251 | Tasa éxito:  26.0% | p_attack media:  0.734 | dist media:  1.000
# [AttackLogger] Episodios:  15000 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:  15100 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:  15200 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.858 | dist media:  1.000
# [AttackLogger] Episodios:  15300 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.831 | dist media:  1.000
# [AttackLogger] Episodios:  15400 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.851 | dist media:  1.000
# [AttackLogger] Episodios:  15500 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.861 | dist media:  1.000
# [AttackLogger] Episodios:  15600 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  15700 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.873 | dist media:  1.000
# [AttackLogger] Episodios:  15800 | Reward medio:  0.081 | Tasa éxito:   9.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:  15900 | Reward medio:  0.251 | Tasa éxito:  26.0% | p_attack media:  0.733 | dist media:  1.000
# [AttackLogger] Episodios:  16000 | Reward medio:  0.172 | Tasa éxito:  18.0% | p_attack media:  0.824 | dist media:  1.000
# [AttackLogger] Episodios:  16100 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:  16200 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:  16300 | Reward medio:  0.112 | Tasa éxito:  12.0% | p_attack media:  0.863 | dist media:  0.999
# [AttackLogger] Episodios:  16400 | Reward medio:  0.171 | Tasa éxito:  18.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:  16500 | Reward medio:  0.092 | Tasa éxito:  10.0% | p_attack media:  0.864 | dist media:  0.994
# [AttackLogger] Episodios:  16600 | Reward medio:  0.061 | Tasa éxito:   7.0% | p_attack media:  0.882 | dist media:  1.000
# [AttackLogger] Episodios:  16700 | Reward medio:  0.050 | Tasa éxito:   6.0% | p_attack media:  0.909 | dist media:  0.998
# [AttackLogger] Episodios:  16800 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.808 | dist media:  0.993
# [AttackLogger] Episodios:  16900 | Reward medio:  0.073 | Tasa éxito:   8.0% | p_attack media:  0.881 | dist media:  1.000
# [AttackLogger] Episodios:  17000 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.816 | dist media:  1.000
# [AttackLogger] Episodios:  17100 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.857 | dist media:  1.000
# [AttackLogger] Episodios:  17200 | Reward medio:  0.171 | Tasa éxito:  18.0% | p_attack media:  0.803 | dist media:  1.000
# [AttackLogger] Episodios:  17300 | Reward medio:  0.083 | Tasa éxito:   9.0% | p_attack media:  0.836 | dist media:  0.996
# [AttackLogger] Episodios:  17400 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.824 | dist media:  1.000
# [AttackLogger] Episodios:  17500 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  17600 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:  17700 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.844 | dist media:  0.995
# [AttackLogger] Episodios:  17800 | Reward medio:  0.102 | Tasa éxito:  11.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:  17900 | Reward medio:  0.098 | Tasa éxito:  11.0% | p_attack media:  0.860 | dist media:  1.000
# [AttackLogger] Episodios:  18000 | Reward medio:  0.102 | Tasa éxito:  11.0% | p_attack media:  0.848 | dist media:  1.000
# [AttackLogger] Episodios:  18100 | Reward medio:  0.192 | Tasa éxito:  20.0% | p_attack media:  0.777 | dist media:  1.000
# [AttackLogger] Episodios:  18200 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  18300 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.814 | dist media:  1.000
# [AttackLogger] Episodios:  18400 | Reward medio:  0.129 | Tasa éxito:  14.0% | p_attack media:  0.824 | dist media:  1.000
# [AttackLogger] Episodios:  18500 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.848 | dist media:  1.000
# [AttackLogger] Episodios:  18600 | Reward medio:  0.139 | Tasa éxito:  15.0% | p_attack media:  0.844 | dist media:  1.000
# [AttackLogger] Episodios:  18700 | Reward medio:  0.081 | Tasa éxito:   9.0% | p_attack media:  0.869 | dist media:  1.000
# [AttackLogger] Episodios:  18800 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  18900 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.824 | dist media:  0.983
# [AttackLogger] Episodios:  19000 | Reward medio:  0.092 | Tasa éxito:  10.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:  19100 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.825 | dist media:  0.995
# [AttackLogger] Episodios:  19200 | Reward medio:  0.143 | Tasa éxito:  15.0% | p_attack media:  0.838 | dist media:  0.997
# [AttackLogger] Episodios:  19300 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.816 | dist media:  1.000
# [AttackLogger] Episodios:  19400 | Reward medio:  0.191 | Tasa éxito:  20.0% | p_attack media:  0.767 | dist media:  1.000
# [AttackLogger] Episodios:  19500 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  19600 | Reward medio:  0.142 | Tasa éxito:  15.0% | p_attack media:  0.831 | dist media:  1.000
# [AttackLogger] Episodios:  19700 | Reward medio:  0.151 | Tasa éxito:  16.0% | p_attack media:  0.817 | dist media:  0.999
# [AttackLogger] Episodios:  19800 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  19900 | Reward medio:  0.162 | Tasa éxito:  17.0% | p_attack media:  0.819 | dist media:  1.000
# [AttackLogger] Episodios:  20000 | Reward medio:  0.185 | Tasa éxito:  19.0% | p_attack media:  0.801 | dist media:  1.000
# [AttackLogger] Episodios:  20100 | Reward medio:  0.182 | Tasa éxito:  19.0% | p_attack media:  0.803 | dist media:  1.000
# [AttackLogger] Episodios:  20200 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.826 | dist media:  1.000
# [AttackLogger] Episodios:  20300 | Reward medio:  0.190 | Tasa éxito:  20.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:  20400 | Reward medio:  0.030 | Tasa éxito:   4.0% | p_attack media:  0.904 | dist media:  1.000
# [AttackLogger] Episodios:  20500 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.841 | dist media:  1.000
# [AttackLogger] Episodios:  20600 | Reward medio:  0.091 | Tasa éxito:  10.0% | p_attack media:  0.858 | dist media:  1.000
# [AttackLogger] Episodios:  20700 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:  20800 | Reward medio:  0.127 | Tasa éxito:  13.0% | p_attack media:  0.843 | dist media:  0.999
# [AttackLogger] Episodios:  20900 | Reward medio:  0.153 | Tasa éxito:  16.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:  21000 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.824 | dist media:  1.000
# [AttackLogger] Episodios:  21100 | Reward medio:  0.072 | Tasa éxito:   8.0% | p_attack media:  0.886 | dist media:  1.000
# [AttackLogger] Episodios:  21200 | Reward medio:  0.191 | Tasa éxito:  20.0% | p_attack media:  0.780 | dist media:  1.000
# [AttackLogger] Episodios:  21300 | Reward medio:  0.189 | Tasa éxito:  20.0% | p_attack media:  0.797 | dist media:  1.000
# [AttackLogger] Episodios:  21400 | Reward medio:  0.162 | Tasa éxito:  17.0% | p_attack media:  0.801 | dist media:  1.000
# [AttackLogger] Episodios:  21500 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.838 | dist media:  1.000
# [AttackLogger] Episodios:  21600 | Reward medio:  0.123 | Tasa éxito:  13.0% | p_attack media:  0.858 | dist media:  1.000
# [AttackLogger] Episodios:  21700 | Reward medio:  0.137 | Tasa éxito:  15.0% | p_attack media:  0.845 | dist media:  0.992
# [AttackLogger] Episodios:  21800 | Reward medio:  0.171 | Tasa éxito:  18.0% | p_attack media:  0.804 | dist media:  0.999
# [AttackLogger] Episodios:  21900 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.800 | dist media:  1.000
# [AttackLogger] Episodios:  22000 | Reward medio:  0.093 | Tasa éxito:  10.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  22100 | Reward medio:  0.135 | Tasa éxito:  14.0% | p_attack media:  0.819 | dist media:  1.000
# [AttackLogger] Episodios:  22200 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.808 | dist media:  1.000
# [AttackLogger] Episodios:  22300 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.857 | dist media:  0.998
# [AttackLogger] Episodios:  22400 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.849 | dist media:  1.000
# [AttackLogger] Episodios:  22500 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.804 | dist media:  1.000
# [AttackLogger] Episodios:  22600 | Reward medio:  0.080 | Tasa éxito:   9.0% | p_attack media:  0.871 | dist media:  1.000
# [AttackLogger] Episodios:  22700 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.800 | dist media:  1.000
# [AttackLogger] Episodios:  22800 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.785 | dist media:  1.000
# [AttackLogger] Episodios:  22900 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  23000 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.857 | dist media:  1.000
# [AttackLogger] Episodios:  23100 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:  23200 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:  23300 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.824 | dist media:  1.000
# [AttackLogger] Episodios:  23400 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.849 | dist media:  1.000
# [AttackLogger] Episodios:  23500 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:  23600 | Reward medio:  0.200 | Tasa éxito:  21.0% | p_attack media:  0.778 | dist media:  1.000
# [AttackLogger] Episodios:  23700 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:  23800 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.810 | dist media:  1.000
# [AttackLogger] Episodios:  23900 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:  24000 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:  24100 | Reward medio:  0.149 | Tasa éxito:  16.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:  24200 | Reward medio:  0.082 | Tasa éxito:   9.0% | p_attack media:  0.871 | dist media:  1.000
# [AttackLogger] Episodios:  24300 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:  24400 | Reward medio:  0.105 | Tasa éxito:  11.0% | p_attack media:  0.856 | dist media:  1.000
# [AttackLogger] Episodios:  24500 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.814 | dist media:  1.000
# [AttackLogger] Episodios:  24600 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:  24700 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.855 | dist media:  1.000
# [AttackLogger] Episodios:  24800 | Reward medio:  0.070 | Tasa éxito:   8.0% | p_attack media:  0.878 | dist media:  1.000
# [AttackLogger] Episodios:  24900 | Reward medio:  0.081 | Tasa éxito:   9.0% | p_attack media:  0.876 | dist media:  1.000
# [AttackLogger] Episodios:  25000 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  25100 | Reward medio:  0.102 | Tasa éxito:  11.0% | p_attack media:  0.858 | dist media:  1.000
# [AttackLogger] Episodios:  25200 | Reward medio:  0.152 | Tasa éxito:  16.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:  25300 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.855 | dist media:  1.000
# [AttackLogger] Episodios:  25400 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  25500 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.826 | dist media:  1.000
# [AttackLogger] Episodios:  25600 | Reward medio:  0.211 | Tasa éxito:  22.0% | p_attack media:  0.790 | dist media:  1.000
# [AttackLogger] Episodios:  25700 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.814 | dist media:  1.000
# [AttackLogger] Episodios:  25800 | Reward medio:  0.129 | Tasa éxito:  14.0% | p_attack media:  0.816 | dist media:  1.000
# [AttackLogger] Episodios:  25900 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:  26000 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  26100 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:  26200 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:  26300 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.870 | dist media:  1.000
# [AttackLogger] Episodios:  26400 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  26500 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.851 | dist media:  1.000
# [AttackLogger] Episodios:  26600 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.814 | dist media:  1.000
# [AttackLogger] Episodios:  26700 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  26800 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.871 | dist media:  1.000
# [AttackLogger] Episodios:  26900 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.849 | dist media:  1.000
# [AttackLogger] Episodios:  27000 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.800 | dist media:  1.000
# [AttackLogger] Episodios:  27100 | Reward medio:  0.181 | Tasa éxito:  19.0% | p_attack media:  0.800 | dist media:  1.000
# [AttackLogger] Episodios:  27200 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.852 | dist media:  1.000
# [AttackLogger] Episodios:  27300 | Reward medio:  0.152 | Tasa éxito:  16.0% | p_attack media:  0.798 | dist media:  1.000
# [AttackLogger] Episodios:  27400 | Reward medio:  0.163 | Tasa éxito:  17.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:  27500 | Reward medio:  0.153 | Tasa éxito:  16.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  27600 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.838 | dist media:  1.000
# [AttackLogger] Episodios:  27700 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.804 | dist media:  1.000
# [AttackLogger] Episodios:  27800 | Reward medio:  0.153 | Tasa éxito:  16.0% | p_attack media:  0.816 | dist media:  1.000
# [AttackLogger] Episodios:  27900 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.813 | dist media:  1.000
# [AttackLogger] Episodios:  28000 | Reward medio:  0.222 | Tasa éxito:  23.0% | p_attack media:  0.781 | dist media:  1.000
# [AttackLogger] Episodios:  28100 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.858 | dist media:  1.000
# [AttackLogger] Episodios:  28200 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.853 | dist media:  1.000
# [AttackLogger] Episodios:  28300 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.823 | dist media:  1.000
# [AttackLogger] Episodios:  28400 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.815 | dist media:  1.000
# [AttackLogger] Episodios:  28500 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.795 | dist media:  1.000
# [AttackLogger] Episodios:  28600 | Reward medio:  0.144 | Tasa éxito:  15.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:  28700 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:  28800 | Reward medio:  0.121 | Tasa éxito:  13.0% | p_attack media:  0.835 | dist media:  1.000
# [AttackLogger] Episodios:  28900 | Reward medio:  0.101 | Tasa éxito:  11.0% | p_attack media:  0.864 | dist media:  1.000
# [AttackLogger] Episodios:  29000 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:  29100 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.805 | dist media:  1.000
# [AttackLogger] Episodios:  29200 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.864 | dist media:  1.000
# [AttackLogger] Episodios:  29300 | Reward medio:  0.171 | Tasa éxito:  18.0% | p_attack media:  0.805 | dist media:  1.000
# [AttackLogger] Episodios:  29400 | Reward medio:  0.111 | Tasa éxito:  12.0% | p_attack media:  0.848 | dist media:  1.000
# [AttackLogger] Episodios:  29500 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:  29600 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  29700 | Reward medio:  0.060 | Tasa éxito:   7.0% | p_attack media:  0.874 | dist media:  1.000
# [AttackLogger] Episodios:  29800 | Reward medio:  0.181 | Tasa éxito:  19.0% | p_attack media:  0.811 | dist media:  1.000
# [AttackLogger] Episodios:  29900 | Reward medio:  0.181 | Tasa éxito:  19.0% | p_attack media:  0.780 | dist media:  1.000
# [AttackLogger] Episodios:  30000 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.831 | dist media:  1.000
# [AttackLogger] Episodios:  30100 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.857 | dist media:  1.000
# [AttackLogger] Episodios:  30200 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.808 | dist media:  1.000
# [AttackLogger] Episodios:  30300 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:  30400 | Reward medio:  0.131 | Tasa éxito:  14.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  30500 | Reward medio:  0.141 | Tasa éxito:  15.0% | p_attack media:  0.833 | dist media:  1.000
# [AttackLogger] Episodios:  30600 | Reward medio:  0.161 | Tasa éxito:  17.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  30700 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:  30800 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  30900 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.826 | dist media:  1.000
# [AttackLogger] Episodios:  31000 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:  31100 | Reward medio:  0.200 | Tasa éxito:  21.0% | p_attack media:  0.768 | dist media:  1.000
# [AttackLogger] Episodios:  31200 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.846 | dist media:  1.000
# [AttackLogger] Episodios:  31300 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.831 | dist media:  1.000
# [AttackLogger] Episodios:  31400 | Reward medio:  0.210 | Tasa éxito:  22.0% | p_attack media:  0.772 | dist media:  1.000
# [AttackLogger] Episodios:  31500 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.862 | dist media:  1.000
# [AttackLogger] Episodios:  31600 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.838 | dist media:  1.000
# [AttackLogger] Episodios:  31700 | Reward medio:  0.190 | Tasa éxito:  20.0% | p_attack media:  0.789 | dist media:  1.000
# [AttackLogger] Episodios:  31800 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.852 | dist media:  1.000
# [AttackLogger] Episodios:  31900 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.860 | dist media:  1.000
# [AttackLogger] Episodios:  32000 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  32100 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.797 | dist media:  1.000
# [AttackLogger] Episodios:  32200 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:  32300 | Reward medio:  0.080 | Tasa éxito:   9.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:  32400 | Reward medio:  0.080 | Tasa éxito:   9.0% | p_attack media:  0.873 | dist media:  1.000
# [AttackLogger] Episodios:  32500 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.796 | dist media:  1.000
# [AttackLogger] Episodios:  32600 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.841 | dist media:  1.000
# [AttackLogger] Episodios:  32700 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:  32800 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:  32900 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.807 | dist media:  1.000
# [AttackLogger] Episodios:  33000 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.840 | dist media:  1.000
# [AttackLogger] Episodios:  33100 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:  33200 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.825 | dist media:  1.000
# [AttackLogger] Episodios:  33300 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  33400 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  33500 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.837 | dist media:  1.000
# [AttackLogger] Episodios:  33600 | Reward medio:  0.190 | Tasa éxito:  20.0% | p_attack media:  0.778 | dist media:  1.000
# [AttackLogger] Episodios:  33700 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.817 | dist media:  1.000
# [AttackLogger] Episodios:  33800 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  33900 | Reward medio:  0.190 | Tasa éxito:  20.0% | p_attack media:  0.808 | dist media:  1.000
# [AttackLogger] Episodios:  34000 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:  34100 | Reward medio:  0.200 | Tasa éxito:  21.0% | p_attack media:  0.791 | dist media:  1.000
# [AttackLogger] Episodios:  34200 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  34300 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.865 | dist media:  1.000
# [AttackLogger] Episodios:  34400 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.854 | dist media:  1.000
# [AttackLogger] Episodios:  34500 | Reward medio:  0.190 | Tasa éxito:  20.0% | p_attack media:  0.799 | dist media:  1.000
# [AttackLogger] Episodios:  34600 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.818 | dist media:  1.000
# [AttackLogger] Episodios:  34700 | Reward medio:  0.220 | Tasa éxito:  23.0% | p_attack media:  0.781 | dist media:  1.000
# [AttackLogger] Episodios:  34800 | Reward medio:  0.080 | Tasa éxito:   9.0% | p_attack media:  0.863 | dist media:  1.000
# [AttackLogger] Episodios:  34900 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.788 | dist media:  1.000
# [AttackLogger] Episodios:  35000 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.821 | dist media:  1.000
# [AttackLogger] Episodios:  35100 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.845 | dist media:  1.000
# [AttackLogger] Episodios:  35200 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.799 | dist media:  1.000
# [AttackLogger] Episodios:  35300 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.830 | dist media:  1.000
# [AttackLogger] Episodios:  35400 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.842 | dist media:  1.000
# [AttackLogger] Episodios:  35500 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.888 | dist media:  1.000
# [AttackLogger] Episodios:  35600 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:  35700 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.809 | dist media:  1.000
# [AttackLogger] Episodios:  35800 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:  35900 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  36000 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.843 | dist media:  1.000
# [AttackLogger] Episodios:  36100 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.838 | dist media:  1.000
# [AttackLogger] Episodios:  36200 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.863 | dist media:  1.000
# [AttackLogger] Episodios:  36300 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.768 | dist media:  1.000
# [AttackLogger] Episodios:  36400 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.816 | dist media:  1.000
# [AttackLogger] Episodios:  36500 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.795 | dist media:  1.000
# [AttackLogger] Episodios:  36600 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.809 | dist media:  1.000
# [AttackLogger] Episodios:  36700 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.848 | dist media:  1.000
# [AttackLogger] Episodios:  36800 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  36900 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.867 | dist media:  1.000
# [AttackLogger] Episodios:  37000 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.836 | dist media:  1.000
# [AttackLogger] Episodios:  37100 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.820 | dist media:  1.000
# [AttackLogger] Episodios:  37200 | Reward medio:  0.170 | Tasa éxito:  18.0% | p_attack media:  0.802 | dist media:  1.000
# [AttackLogger] Episodios:  37300 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.811 | dist media:  1.000
# [AttackLogger] Episodios:  37400 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.787 | dist media:  1.000
# [AttackLogger] Episodios:  37500 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.788 | dist media:  1.000
# [AttackLogger] Episodios:  37600 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.809 | dist media:  1.000
# [AttackLogger] Episodios:  37700 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.812 | dist media:  1.000
# [AttackLogger] Episodios:  37800 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.847 | dist media:  1.000
# [AttackLogger] Episodios:  37900 | Reward medio:  0.070 | Tasa éxito:   8.0% | p_attack media:  0.870 | dist media:  1.000
# [AttackLogger] Episodios:  38000 | Reward medio:  0.160 | Tasa éxito:  17.0% | p_attack media:  0.835 | dist media:  1.000
# [AttackLogger] Episodios:  38100 | Reward medio:  0.140 | Tasa éxito:  15.0% | p_attack media:  0.828 | dist media:  1.000
# [AttackLogger] Episodios:  38200 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.818 | dist media:  1.000
# [AttackLogger] Episodios:  38300 | Reward medio:  0.180 | Tasa éxito:  19.0% | p_attack media:  0.806 | dist media:  1.000
# [AttackLogger] Episodios:  38400 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.829 | dist media:  1.000
# [AttackLogger] Episodios:  38500 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.839 | dist media:  1.000
# [AttackLogger] Episodios:  38600 | Reward medio:  0.110 | Tasa éxito:  12.0% | p_attack media:  0.860 | dist media:  1.000
# [AttackLogger] Episodios:  38700 | Reward medio:  0.150 | Tasa éxito:  16.0% | p_attack media:  0.831 | dist media:  1.000
# [AttackLogger] Episodios:  38800 | Reward medio:  0.060 | Tasa éxito:   7.0% | p_attack media:  0.899 | dist media:  1.000
# [AttackLogger] Episodios:  38900 | Reward medio:  0.130 | Tasa éxito:  14.0% | p_attack media:  0.832 | dist media:  1.000
# [AttackLogger] Episodios:  39000 | Reward medio:  0.220 | Tasa éxito:  23.0% | p_attack media:  0.773 | dist media:  1.000
# [AttackLogger] Episodios:  39100 | Reward medio:  0.060 | Tasa éxito:   7.0% | p_attack media:  0.870 | dist media:  1.000
# [AttackLogger] Episodios:  39200 | Reward medio:  0.080 | Tasa éxito:   9.0% | p_attack media:  0.880 | dist media:  1.000
# [AttackLogger] Episodios:  39300 | Reward medio:  0.120 | Tasa éxito:  13.0% | p_attack media:  0.858 | dist media:  1.000
# [AttackLogger] Episodios:  39400 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.867 | dist media:  1.000
# [AttackLogger] Episodios:  39500 | Reward medio:  0.230 | Tasa éxito:  24.0% | p_attack media:  0.751 | dist media:  1.000
# [AttackLogger] Episodios:  39600 | Reward medio:  0.190 | Tasa éxito:  20.0% | p_attack media:  0.816 | dist media:  1.000
# [AttackLogger] Episodios:  39700 | Reward medio:  0.100 | Tasa éxito:  11.0% | p_attack media:  0.864 | dist media:  1.000
# [AttackLogger] Episodios:  39800 | Reward medio:  0.070 | Tasa éxito:   8.0% | p_attack media:  0.882 | dist media:  1.000
# [AttackLogger] Episodios:  39900 | Reward medio:  0.090 | Tasa éxito:  10.0% | p_attack media:  0.827 | dist media:  1.000
# [AttackLogger] Episodios:  40000 | Reward medio:  0.060 | Tasa éxito:   7.0% | p_attack media:  0.890 | dist media:  1.000

# %%
# Configuración de gráficos para visualizar los resultados
plt.style.use("seaborn-v0_8-whitegrid")

# Datos para graficar
episodes = np.array(callback_PPO.history_episodes)
success_rate = np.array(callback_PPO.history_success_rate) * 100
mean_reward = np.array(callback_PPO.history_mean_reward)
mean_p_attack = np.array(callback_PPO.history_mean_p_attack)

# %%
# Gáfico de Tasa de éxito
success_rate = np.array(callback_PPO.history_success_rate) * 100

# Suavizado
window = 5
smooth_success = uniform_filter1d(success_rate, size=window)
mean = smooth_success
std = uniform_filter1d(np.abs(success_rate - mean), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Grafico de Tasa de éxito
plt.plot(episodes, mean, linewidth=2.2, color="#007acc")
plt.fill_between(
    episodes,
    mean - std,
    mean + std,
    color="#007acc",
    alpha=0.15
)
plt.title("Tasa de éxito del atacante", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Éxito (%)", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Reward medio
mean_reward = np.array(callback_PPO.history_mean_reward)

# Suavizado
window = 5
smooth_reward = uniform_filter1d(mean_reward, size=window)

# Desviación estándar local
std_reward = uniform_filter1d(np.abs(mean_reward - smooth_reward), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_reward, linewidth=2.2, color="#d35400")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_reward - std_reward,
    smooth_reward + std_reward,
    color="#d35400",
    alpha=0.15
)
plt.title("Reward medio por ventana (100 episodios)", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("Reward", fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Probabilidad media de ataque
mean_p_attack = np.array(callback_PPO.history_mean_p_attack)

# Suavizado
window = 5
smooth_p_attack = uniform_filter1d(mean_p_attack, size=window)

# Desviación estándar local
std_p_attack = uniform_filter1d(np.abs(mean_p_attack - smooth_p_attack), size=window)

# Configuración del gráfico
plt.figure(figsize=(10,6), dpi=130)

# Línea suavizada
plt.plot(episodes, smooth_p_attack, linewidth=2.2, color="#8e44ad")

# Banda difuminada
plt.fill_between(
    episodes,
    smooth_p_attack - std_p_attack,
    smooth_p_attack + std_p_attack,
    color="#8e44ad",
    alpha=0.15
)
plt.title("Probabilidad media final de ataque", fontsize=16, fontweight="bold")
plt.xlabel("Episodios", fontsize=13)
plt.ylabel("p_attack", fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluación de PPO

# %%
# Creamos un entorno vectorizado para evaluación
eval_env = DummyVecEnv([make_env])

# Cargamos la normalización del entorno usado en entrenamiento
eval_env = VecNormalize.load("../../agents/v1/ppo_attacker_limited_multistep_vecnorm.pkl", eval_env)

# Desactivamos el entrenamiento, de manera que las estadísticas de normalización no se actualicen durante la evaluación 
eval_env.training = False

# Desactivamos la normalización de recompensas para la evaluación (cuando evaluamos queremos las recompensas reales)
eval_env.norm_reward = False

# Cargamos el modelo entrenado
model = PPO.load("../../agents/v1/ppo_attacker_limited_multistep")

# Evaluamos el agente PPO atacante con 300 episodios
success_rate, mean_final_p, mean_final_dist = evaluate_sac_attacker(model, eval_env, n_episodes=300)

# Mostramos los resultados finales de la evaluación
print(f"Tasa de evasión (episodio completo, PPO): {success_rate*100:.3f}%")
print(f"Probabilidad media final de ataque (PPO): {mean_final_p*100:.3f}%")
print(f"Distancia media final de la perturbación: {mean_final_dist:.3f}") # La distancia media entre x_adv y x_orig (tamaño medio de la perturbación)
# Out:
# Tasa de evasión (episodio completo, PPO): 12.667%
# Probabilidad media final de ataque (PPO): 84.917%
# Distancia media final de la perturbación: 1.000

# %%
# Muestreamos 300 ataques adversariales generados por el agente PPO multi-step
xs_orig, xs_adv, successes, mean_final_dist  = sample_adversarials_multistep(model, eval_env, n_episodes=300)

# Configuración de gráficos
plt.figure(figsize=(6, 6))

# Pintamos los ataques originales de color azul claro
plt.scatter(xs_orig[:, 0], xs_orig[:, 1], alpha=0.3, label="Original (ataque)")

# Pintamos los ataques adversariales que lograron evadir el detector de color naranja
mask_ok = successes == 1
plt.scatter(xs_adv[mask_ok, 0], xs_adv[mask_ok, 1], alpha=0.7, label="Adversarial (evade)")
plt.legend()
plt.grid(True)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Ataques adversariales aprendidos por el agente (multi-step SAC)")
plt.show()
